# %% [markdown]
# # Preface
#
# Upon research, I found a favourable approach to further pre-training was to perform further within-task or in-domain pretraining from the existing BERT model checkpoint.
#
# I've already collected around 150,000 tweets that are categorized as either hate speech, offensive or benign so this roughly satisfies the requirement that the pretraining data is within-task or in-domain.
#
# However there are far more tweet databases that can be used to further-pretrain my BERT model. There is a wealth of unsupervised tweet datasets online that I can make use of, these datasets often do not come in text form but rather the tweets are represented by their tweet IDs. Below I will describe the tweet datasets and retrieve their associated text using the tweepy module.

# %% [markdown]
# # Retrieving more pre-training data from unsupervised tweet datasets
# Using as wide a variety of sources as possible, we will increase the knowledge of our further-pretrained model. My goal when sourcing these datasets was to try and find tweet datasets which are largely user-generated, as hate speech online largely comes from user generated content.
#
# If I could find it, I would use tweet datasets likely to have aggressive or abusive content as well as possibly containing sexist and racial slurs. Even having some tweets just talking about racial, gender or sexuality based issues would be beneficial for my model to be trained on as these tweets use the language associated with these issues.
#
# The following tweets can all be retrieved by ID and they come from the following sources:
#
#
# *   ### <b>#UniteTheRight tweet database:</b>
#
# The Unite the Right rally (also known as the Charlottesville rally) was a protest in Charlottesville, Virginia, United States from August 11–12, 2017, to oppose the removal of a statue of Robert E. Lee in Emancipation Park, which itself was renamed from Lee Park two months earlier. Protesters included white supremacists, white nationalists, neo-Confederates, neo-Nazis, and militias. This dataset contains 200,113 tweet ids collected with the #unitetheright hashtag. The time ranges for the tweets are from 2017-08-04 11:44:12 to 2017-08-15 16:03:30 GMT.
#
# *   ### <b>Bill 10 Twitter IDs:</b>
#
# A list of 24876 Twitter IDs for tweets harvested between Nov. 28 and Dec. 6 2014 containing the hashtag #bill10. Bill 10 in the Alberta legislature would have given public and Catholic school boards the right to refuse student requests to form gay-straight alliances in schools. Under intense public interest it was withdrawn by the Conservative government.
#
# *  ### <b>BLMKidnapping:</b>
#
# These 136,990 tweet ids represent reaction to a Facebook Live video that was posted on January 3rd, 2017, showing four African American men violently attacking a white, mentally disabled man. The tweets were collected on 01/05/2017. After the video surfaced, the Twitter hashtag, #BLMkidnapping, was created and used to incorrectly attribute the violent attack to members of the Black Lives Matter movement. Police in Chicago, where the attack took place, have found no evidence the attack has any connection to the Black Lives Matter movement. This link is to a CNN story documenting the police denial of Black Lives Matter connection: http://www.cnn.com/2017/01/05/us/black-lives-matter-chicago-facebook-live-beating/index.html
#
# *   ### <b>#Charlottesville:</b>
#
# On Friday, August 11th, 2017 large groups of racist white nationalists carrying torches marched on the University of Virginia campus in Charlottesville, VA as an intimidation tactic against proponents for the removal of confederate statues of Robert E. Lee. The Friday evening march was held ahead of a much larger racist white nationalist rally in the center of Charlottesville planned for Saturday, August 12th, 2017.
#
# *   ### <b>Replies to Ocasio-Cortez Tweets:</b>
#
# Replies to senator Rep. Alexandria Ocasio-Cortez’s Tweets and Retweets in March 2019. Whilst many tweets to Ms. Ocasio-Cortez may be glowing praise, I'm counting on a sizable portion of the tweets directed at her to be abusive and perhaps sexist and racist - I feel like this is a safe enough hypothesis, as america's political climate has become much more toxic in recent years.

# %% [markdown]
# Importing and Installing Dependencies ...

# %%
# !pip install tweepy
# !pip install google-cloud-storage
# !pip install gcsfs
# Out:
# Requirement already satisfied: tweepy in c:\users\fionn\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\fionn\anaconda3\lib\site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\fionn\anaconda3\lib\site-packages (from tweepy) (1.7.1)
# Requirement already satisfied: requests>=2.11.1 in c:\users\fionn\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\fionn\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\fionn\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.25.7)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\fionn\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\fionn\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fionn\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\fionn\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: google-cloud-storage in c:\users\fionn\anaconda3\lib\site-packages (1.24.1)
# Requirement already satisfied: google-resumable-media<0.6dev,>=0.5.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-cloud-storage) (0.5.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.1.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-cloud-storage) (1.1.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.9.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-cloud-storage) (1.10.0)
# Requirement already satisfied: six in c:\users\fionn\anaconda3\lib\site-packages (from google-resumable-media<0.6dev,>=0.5.0->google-cloud-storage) (1.12.0)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (1.15.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-storage) (44.0.0.post20200106)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-storage) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-storage) (0.2.7)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.9.0->google-cloud-storage) (4.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (2.22.0)
# Requirement already satisfied: protobuf>=3.4.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (3.10.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (1.6.0)
# Requirement already satisfied: pytz in c:\users\fionn\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (2019.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\fionn\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.9.0->google-cloud-storage) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fionn\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\fionn\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\fionn\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (1.25.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\fionn\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.1.0->google-cloud-storage) (3.0.4)
# Requirement already satisfied: gcsfs in c:\users\fionn\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: requests in c:\users\fionn\anaconda3\lib\site-packages (from gcsfs) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\fionn\anaconda3\lib\site-packages (from gcsfs) (0.4.1)
# Requirement already satisfied: decorator in c:\users\fionn\anaconda3\lib\site-packages (from gcsfs) (4.4.1)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\fionn\anaconda3\lib\site-packages (from gcsfs) (0.6.2)
# Requirement already satisfied: google-auth>=1.2 in c:\users\fionn\anaconda3\lib\site-packages (from gcsfs) (1.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fionn\anaconda3\lib\site-packages (from requests->gcsfs) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\fionn\anaconda3\lib\site-packages (from requests->gcsfs) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\fionn\anaconda3\lib\site-packages (from requests->gcsfs) (1.25.7)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\fionn\anaconda3\lib\site-packages (from requests->gcsfs) (2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth-oauthlib->gcsfs) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs) (3.1.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs) (1.12.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs) (0.2.7)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs) (44.0.0.post20200106)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in c:\users\fionn\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs) (4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\fionn\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\fionn\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.4.8)

# %%
import os
import pandas as pd
import re
import json
import tweepy

#Below is to authenticate google bucket access for local machines

#Put GCS service account credentials json in current working directory
#Not in github repo because it's private info
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]= "./storageCreds.json"
from google.cloud import storage
storage_client = storage.Client()
buckets = list(storage_client.list_buckets())
print(buckets) # Testing if access to GCS has been granted

pd.set_option('display.max_colwidth', -1) # Set col width to -1 so we can see entire text column

#Below is for google colab environment
"""from google.colab import auth
auth.authenticate_user()
# !gcloud config set project 'my-project-csc3002'"""
# Out:
# [<Bucket: csc3002>]
# "from google.colab import auth\nauth.authenticate_user()\n!gcloud config set project 'my-project-csc3002'"

# %% [markdown]
# **Combining tweet ID dataframes**

# %%
#UniteTheRight
utr = 'gs://csc3002/pretrain_data/tweetIDs/UniteTheRight.txt'
utr = pd.read_csv(utr, sep=',',  index_col = False, encoding = 'utf-8', header = None, names = ['id'])
print("#UniteTheRight tweet database contains", len(utr.index), "tweet IDs")

#Bill 10
b10 = 'gs://csc3002/pretrain_data/tweetIDs/bill10tweets.txt'
b10 = pd.read_csv(b10, sep=',',  index_col = False, encoding = 'utf-8', header = None, names = ['id'])
print("\nBill 10 tweet database contains", len(b10.index), "tweet IDs")

#BlmKidnapping
blm = 'gs://csc3002/pretrain_data/tweetIDs/blmkidnapping_tweet_ids_v1.txt'
blm = pd.read_csv(blm, sep=',',  index_col = False, encoding = 'utf-8', header = None, names = ['id'])
print("\n#blmkidnapping tweet database contains", len(blm.index), "tweet IDs")

#Ocasio-Cortez Replies
aoc = 'gs://csc3002/pretrain_data/tweetIDs/ocasio_cortez_replies.csv'
aoc = pd.read_csv(aoc, sep=',',  index_col = False, encoding = 'utf-8', header = 0, names = ['id'])
print("\nAOC tweet database contains", len(aoc.index), "tweet IDs")
# Out:
# #UniteTheRight tweet database contains 200113 tweet IDs
#
# Bill 10 tweet database contains 24876 tweet IDs
#
# #blmkidnapping tweet database contains 136990 tweet IDs
#
# AOC tweet database contains 109201 tweet IDs

# %% [markdown]
# Now combining all of the tweet IDs into a single dataframe.

# %%
full = pd.concat([aoc, blm, b10, utr], axis =0)
full.drop_duplicates(subset='id',inplace =True ) #Important to drop duplicates

#Shuffle Data
full = full.sample(frac=1)
full.reset_index(drop = True, inplace = True)

print("There are", len(full.index), "tweet IDs in this dataset")
full.head()
# Out:
# There are 471180 tweet IDs in this dataset
#                     id
# 0  1103682676794552320
# 1  896382208172113921
# 2  896755993769410560
# 3  540344228853719040
# 4  816863154391158784

# %% [markdown]
# Below is a tweepy method to obtain tweets via ID. Twitter API only allows us to extract tweets 100 at a time, as there are rate limits - therfore, we must set the wait_on_rate_limit parameter to True.

# %%
def lookup_tweets(tweet_IDs, api):
    
    full_tweets = []
    tweet_count = len(tweet_IDs)
    print("\nThere are", tweet_count, "tweet IDs to fetch")
    
    #Catching error if empty list
    if tweet_count < 1:
        return full_tweets
    
    #Below code to monitor progress
    #It's divided by 500 because we retrieve tweets via API call 100 at a time.
    #and we're looking to monitor progess each 5th of the way complete
    x = int(tweet_count/500) 
    progress = {x: '20%', x*2: '40%', x*3: '60%', x*4: '80%'}
    print("Fetching tweets...")
    try:
        for i in range((tweet_count // 100) + 1):
            if i in list(progress.keys()):
                print(progress[i], "complete")

        
            # Catch the last group if it is less than 100 tweets
            end_loc = min((i + 1) * 100, tweet_count)
            #It was .extend but it is slower than .append
            full_tweets.append(
                api.statuses_lookup(id_=tweet_IDs[i * 100:end_loc], map_ = True))
            
        return full_tweets
    
    except tweepy.TweepError as e:
        print("Around index:", i*100, "\n", e.reason) 
        
        #Recursive call to continue even with exception
        return full_tweets + lookup_tweets(tweet_IDs[(i+1)*100:tweet_count], api)
                

#Google colab
"""from google.colab import drive
drive.mount('/content/drive')
with open('/content/drive/My Drive/twitter_credentials.json', "r") as f:
  creds = json.load(f)"""

#Again, like storageCreds. json is not in the github repo. But will have to be put in
#local directory in orderto use tweepy API
with open('./twitter_credentials.json', "r") as f:
    creds = json.load(f)


auth = tweepy.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
auth.set_access_token(creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])

api = tweepy.API(auth, wait_on_rate_limit=True,  wait_on_rate_limit_notify=True, \
                 retry_count=10, retry_delay=5, retry_errors=set([503])) # These last three params catch over-capacity error

# %% [markdown]
# Applying the custom tweepy function to this dataframe to retrieve the text content corresponding to each tweet ID, then wrangling all of the text data into a singular dataframe.
#
# <b>The below cell may take a while to run.</b>

# %%
tweet_ids = list(full['id'])

#Below works as long as len(tweet_ids) is not a multiple of 100. Takes a while
results = lookup_tweets(tweet_ids, api)

temp = ""
final = pd.DataFrame() 
for i, obj in enumerate(results):
    
    temp = json.dumps([status._json for status in results[i]])#create JSON string
    temp_df = pd.read_json(temp, orient='records')
    temp_df = temp_df[['id','text']]
    final = final.append(temp_df, ignore_index = True)
    
pd.set_option('display.max_colwidth', -1)
print(final.info())
final.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471180 entries, 0 to 471179
# Data columns (total 2 columns):
# id      471180 non-null int64
# text    230163 non-null object
# dtypes: int64(1), object(1)
# memory usage: 7.2+ MB
# None
#                     id  \
# 0  816849890789752832
# 1  816831990338945024
# 2  1102870750367752192
# 3  896524739753132032
# 4  1103682676794552320
#
#                                                                                                                                            text
# 0  White kid, kid napped by black people outrage, black person shot by white cops silence #BLMKidnapping
# 1  RT @hottiesfortrump: Instances like the  #BLMKidnapping is what got trump elected.
# 2  @thehill @AOC https://t.co/IJmyar9HAR
# 3  NaN
# 4  @Mylife47778820 @RashidaTlaib @IlhanMN Yes I think you have to say that to your leader trump he like no one non whi… https://t.co/Njoqm9OKh8

# %% [markdown]
# It'll be interesting to see if the amount of NaNs is the result of an error in my code, the database or if it's just banned accounts

# %%
#Quick function to beautify the error message
def getExceptionMessage(msg):
    words = msg.split(' ')

    errorMsg = ""
    for index, word in enumerate(words):
        if index not in [0,1,2]:
            errorMsg = errorMsg + ' ' + word
    errorMsg = errorMsg.rstrip("\'}]")
    errorMsg = errorMsg.lstrip(" \'")

    return errorMsg

def getErrorDesc(df): 
    for row in range(0, len(df.index)):
        current = df.loc[row]
        if pd.isna(current.text) == True:  
            try:    
                twt = api.get_status(current.id)
            except tweepy.TweepError as err:
                df.loc[row, 'text'] = getExceptionMessage(err.reason)
    return df

#If I attempt this with the whole dataset it'll take ages,
#So I'll just randomly sample the dataset to get a rough idea
df = final.sample(1000)
df.reset_index(drop = True, inplace = True)
print(df.info(), '\n\n')

df = getErrorDesc(df)
print("\n", df.text.value_counts()[1:10])
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
# id      1000 non-null int64
# text    505 non-null object
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB
# None
#
#
#
#  No status found with that ID.                                                                                                                        229
# Sorry, you are not authorized to see this status.                                                                                                    21
# RT @AynRandPaulRyan: David Duke in #Charlottesville saying this Nazi, #UniteTheRight fiasco "fulfills the promises of Donald Trump." \nhttps…        20
# Sorry, that page does not exist.                                                                                                                     10
# RT @RVAwonk: Here's former KKK leader David Duke explicitly stating that Trump motivated the white supremacist #UniteTheRight rally in #Cha…         8
# RT @RealAlexRubi: Massive brawl breaks out, tiki torches thrown as #UniteTheRight reaches Jefferson monument in #Charlottesville. Chemicals…         6
# RT @JDeanSeal: This is the car that plowed through a crowd at the #UniteTheRight rally. Stopped along Monticello Ave. https://t.co/7Uf4lHfA…         6
# RT @dtxErgaOmnes: Jason Kessler organized the #UniteTheRight rally. He deserves the shaming for organizing &amp; the violence it incited.\nhttps…    5
# RT @UR_Ninja: Car plows into #antifascist protest in #Charlottesville Many people injured, some possibly dead #Defendcville #UniteTheRight…          4
# Name: text, dtype: int64
#                     id  \
# 0  1110674175960776704
# 1  1108431292394336256
# 2  896488360482488320
# 3  816876638231298049
# 4  1107062014764036098
# 5  816873484378722305
# 6  896437970705821697
# 7  1109959913353216000
# 8  1104549953005793280
# 9  896443192828211200
#
#                                                                                                                                            text
# 0  @AOC What an overwhelming show of support on your vote.   You must be so proud!\n\nHahahahahahahahaaaahahhhhhhaaaaa Ouch I broke a rib
# 1  @storyseen @kylegriffin1 An article from 2002. It was so pressing it only took 17 years to introduce legislation. N… https://t.co/sJxhiwcaFG
# 2  RT @LawyersComm: #UniteTheRight's #Charlottesville rally is an attempt to divide this country. Help us #StopHate by visiting https://t.co/3…
# 3  No status found with that ID.
# 4  @AOC I traveled an hour and a half up and back to go from the end of the IRT line in Brooklyn to attend engineering… https://t.co/TUiSCYU8NH
# 5  User has been suspended.
# 6  User has been suspended.
# 7  @LanceAHerring1 @judithfinnemore @AOC Excellent!
# 8  No status found with that ID.
# 9  RT @JDeanSeal: This is the car that plowed through a crowd at the #UniteTheRight rally. Stopped along Monticello Ave. https://t.co/7Uf4lHfA…

# %% [markdown]
# Interesting that not only has our function above showcased the errors associated, but also it's shown that there are many duplicate tweets as the result of RTs. We can remove this through the drop duplicates method

# %% [markdown]
# <b>Now concatenating the charlottesville dataset which already has the tweets associated with each ID so no text retrieval function via tweepy is necessary</b>

# %%
nullvals = final.text.isna().sum()
print("Amount of tweets IDs not returning text:", nullvals)
per = (nullvals/len(final.index)) * 100
print(("Which is %.2f%% of the overall dataset") % (per))
# Out:
# Amount of tweets IDs not returning text: 241017
# Which is 51.15% of the overall dataset

# %%
final.dropna(inplace = True)
final.reset_index(drop=True, inplace = True)
final.tail()
# Out:
#                          id  \
# 235546  896201447838187520
# 235547  896835566624546816
# 235548  1102729934894653440
# 235549  1103276581060005889
# 235550  896247350808784896
#
#                                                                                                                                  text
# 235546  happening now at uva. our people on the march. will you be at #unitetheright tomorrow?
# 235547  jason kessler organized the #unitetheright rally. he deserves the shaming for organizing &amp; the violence it incited. https
# 235548  i 2nd that shout out!
# 235549  perhaps it is just a
# 235550  alt right #unitetheright woman tells #antifa counter-protester that he "sounds like a n-----" #charlottesville

# %%
#Charlottesville - Contains full text in columns
charl = 'gs://csc3002/pretrain_data/tweetIDs/charlottesville_aug15_sample.csv'
charl = pd.read_csv(charl, sep=',',  index_col = False, encoding = 'utf-8', header = 0,)
charl1 = 'gs://csc3002/pretrain_data/tweetIDs/aug16_sample.csv'
charl1 = pd.read_csv(charl1, sep=',',  index_col = False, encoding = 'utf-8', header = 0,)
charl2 = 'gs://csc3002/pretrain_data/tweetIDs/aug17_sample.csv'
charl2 = pd.read_csv(charl2, sep=',',  index_col = False, encoding = 'utf-8', header = 0,)
charl3 = 'gs://csc3002/pretrain_data/tweetIDs/aug18_sample.csv'
charl3 = pd.read_csv(charl3, sep=',',  index_col = False, encoding = 'utf-8', header = 0,)

dfs = [charl[['id','full_text']], charl1[['id','full_text']], \
       charl2[['id','full_text']], charl3[['id','full_text']]]
       
charlot = pd.concat(dfs, axis = 0)
charlot.rename(columns = {'full_text':'text'}, inplace = True)
print("\n#Charlottesville tweet database contains", len(charlot.index), "tweet IDs")

print(charlot.info())
charlot.head()
# Out:
# #Charlottesville tweet database contains 200000 tweet IDs
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 0 to 49999
# Data columns (total 2 columns):
# id      200000 non-null int64
# text    200000 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.6+ MB
# None
#                    id  \
# 0  897661668787982336
# 1  897654901534228480
# 2  897659748597870592
# 3  897660496656179202
# 4  897642311903055872
#
#                                                                                                                                     text
# 0  It's almost as if people are exactly who they say they are https://t.co/MnWFXZd9c3
# 1  @Slate Conservative media: Yes, Trump's response to Charlottesville was bad, but what about Obama? https://t.co/jjINXL5Qp0 via @slate
# 2  👀 https://t.co/qeyzYeblwu
# 3  😂 😂 😂 Karma really isn't wasting time.. https://t.co/JYRqf6vlSX
# 4  After Charlottesville, Black Lives Matter Issues New Demand - https://t.co/Vuw3IvrhL2

# %%
final1 = pd.concat([final, charlot], axis = 0)
final1 = final1.sample(frac=1) #shuffle
final1['text'] = final1['text'].astype(str)
final1['text'] = final1['text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
final1.reset_index(drop = True, inplace = True)
final1.drop_duplicates(subset='text',inplace =True )
print("There are ", len(final1.index), "unique tweets in this database\n")
final1.to_csv('gs://csc3002/pretrain_data/tweetText/full.csv', sep = ',', encoding='utf-8', \
                 index = False, header = True)
final1.info()
# Out:
# There are  329720 unique tweets in this database
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 329720 entries, 0 to 671175
# Data columns (total 2 columns):
# id      329720 non-null int64
# text    329720 non-null object
# dtypes: int64(1), object(1)
# memory usage: 7.5+ MB

# %% [markdown]
# ## More pre-training data... Specifically datasets likely to have women or immigrants as the subject
#
# The main hate speech dataset I'll be testing with will be the HatEval dataset, which has women and immigrants as their target. With this in mind, I sought to source more tweet datasets which were likely to have women or immigrants as the subject
# *   ### <b>#thechalkening tweet database:</b>
#
# The Chalkening is a campaign launched by Donald Trump supporters on college campuses that involves writing pro-Trump messages in chalk on campus facilities. This mass, chalk-based, protest happened alongside an outpouring of media criticism of an incident at Emory University in March 2016. An Emory university administrator sent an email expressing support for students who claimed to feel threatened and unsafe by hate speech in the form of pro-Trump chalkings on the campus.

# %%
chalkening = pd.read_csv('gs://csc3002/pretrain_data/tweetIDs/thechalkening-ids-20160412.txt', sep=',',  index_col = False, header=None, names =['id'])

chalkening1 = pd.read_csv('gs://csc3002/pretrain_data/tweetIDs/thechalkening-ids-20160615.txt', sep=',',  index_col = False, header=None, names =['id'])

chalk = pd.concat([chalkening, chalkening1], axis = 0)
print("There are", len(chalk.index), "tweets with the #chalkening hashtag")
# Out:
# There are 115524 tweets with the #chalkening hashtag

# %%
tweet_ids = list(chalk['id'])

#Below works as long as it's not a multiple of 100. takes a while
results = lookup_tweets(tweet_ids, api)
                                  
temp = ""
final = pd.DataFrame() 
for i, obj in enumerate(results):
    
    temp = json.dumps([status._json for status in results[i]])#create JSON string
    temp_df = pd.read_json(temp, orient='records')
    if 'text' in list(temp_df):
        temp_df = temp_df[['id','text']]
        final = final.append(temp_df, ignore_index = True)
    
pd.set_option('display.max_colwidth', -1)
print(final.info())
final.head()
# Out:
# There are 115524 tweet IDs to fetch
# Fetching tweets...
# 20% complete
# 40% complete
# 60% complete
# 80% complete
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115324 entries, 0 to 115323
# Data columns (total 2 columns):
# id      115324 non-null int64
# text    50984 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.8+ MB
# None
#                    id  \
# 0  720103525401931777
# 1  720118772808474624
# 2  720112336632168448
# 3  720107218495016960
# 4  720123193269338112
#
#                                                                                               text
# 0  RT @DanScavino: #TheChalkening- thank you! #Trump2016 #StudentsForTrump https://t.co/W6aTj6TzzL
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
final.dropna(inplace = True)
final.drop_duplicates(subset='text',inplace =True ) #Important to drop duplicates
final.reset_index(drop=True, inplace = True)

print("After Dropping nulls and duplicate tweets (such as retweets) there are",\
     len(final.index), "tweets")
final['text'] = final['text'].astype(str)
final['text'] = final['text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
final.to_csv('gs://csc3002/pretrain_data/tweetText/chalkTweets.csv', sep = ',', encoding='utf-8', \
                 index = False, header = True)
final.tail(15)
# Out:
# After Dropping nulls and duplicate tweets (such as retweets) there are 8720 tweets
#                       id  \
# 8705  739671052398305281
# 8706  739804103702945792
# 8707  739677331342696448
# 8708  739840239057805312
# 8709  739674668454514688
# 8710  739675025742123008
# 8711  739672908163846144
# 8712  739668137021440000
# 8713  739815224946102272
# 8714  739716451779497984
# 8715  739676305264771072
# 8716  739667266086817792
# 8717  739867836294660097
# 8718  739673219335114752
# 8719  739580349462777856
#
#                                                                                                                                  text
# 8705  #TheChalkening #GameofThrones #OBAMAGATE #SoccerAid2016 https://t.co/m0stELlf8B
# 8706  RT @RockjackOne: Chicago and Detroit are plantations where liberals keep there voters  https://t.co/c10RtXmqUL
# 8707  #TheChalkening #GameofThrones https://t.co/D5JTNMKnet
# 8708  Choose a side. Probably our last chance. #WomenForTrump #TheChalkening #StudentsForTrump #BernieSanders https://t.co/W2sn6jtUJ9
# 8709  #TheChalkening #ThronesYall  #SoccerAid2016 https://t.co/CXhBgLcN4S
# 8710  #ThronesYall #TheChalkening #GameofThrones https://t.co/TtJq8tMjLP
# 8711  RT @LDJT2016: #TheChalkening #GameofThrones #OBAMAGATE #SoccerAid2016 https://t.co/m0stELlf8B
# 8712  #TheChalkening #GameofThrones #OBAMAGATE #SoccerAid2016 #FrenchOpenFinal https://t.co/QQrZP19Ntf
# 8713  #mondaymotivation #TheChalkening #GameofThrones https://t.co/qCfAcDocpl
# 8714  Undeniable. #WomenForTrump #TheChalkening #StudentsForTrump https://t.co/WRjXl74vpK
# 8715  RT @LDJT2016: #ThronesYall #TheChalkening #GameofThrones https://t.co/TtJq8tMjLP
# 8716  #TheChalkening #GameofThrones #OBAMAGATE #FrenchOpenFinal https://t.co/1h2GOAaeGt
# 8717  LA Times article admits it. https://t.co/OrNh0HrLcf\n#WomenForTrump #TheChalkening #StudentsForTrump https://t.co/jg29FHqZi8
# 8718  RT @LDJT2016: #TheChalkening #GameofThrones #OBAMAGATE #NBAFinals https://t.co/4FqtYe0IXN
# 8719  I'm like 3 months late, but here's my retarded addition to #TheChalkening https://t.co/w5egYrKKWg

# %% [markdown]
# <i>There are very few tweets returned surprisingly. There must have been an overload of retweets in the dataset. Still we'll use them in the pre-training regardless</i>

# %%
final.dropna(inplace = True)
final.to_csv('gs://csc3002/pretrain_data/tweetText/chalkTweets.csv', sep = ',', encoding='utf-8', \
                 index = False, header = True)
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8720 entries, 0 to 8719
# Data columns (total 2 columns):
# id      8720 non-null int64
# text    8720 non-null object
# dtypes: int64(1), object(1)
# memory usage: 204.4+ KB

# %% [markdown]
# *   ### <b>#NotAllMen Twitter IDs:</b>
#
# Around 70,000 tweets with the #NotAllMen hashtag. A Time magazine article on the subject states that "Not all men" was previously stated as an object of frustration, but in early 2014 it became usually used as an object of mockery. Intended to counter generalizations about men's behavior, some critics claim the phrase deflects conversations from uncomfortable topics, such as sexual assault.
#
# *   ### <b>#NotAllWomen Twitter IDs:</b>
#
# A counter to the #YesAllWomen protest (explained in more detail later). Many tweets with this hashtag at a glance seem to be quite sexist or at least subversive. Basically a vacant protest on somebody else's protest like #AllLivesMatter

# %%
notallmen = pd.read_csv('gs://csc3002/pretrain_data/tweetIDs/NotAllMen.ids.txt', sep=',',  index_col = False, header=None, names =['id'])
print("There are", len(notallmen.index), "tweets with the #NotAllMen hashtag")

notAllWomen = pd.read_csv('gs://csc3002/pretrain_data/tweetIDs/NotAllWomen.ids.txt', sep=',',  index_col = False, header=None, names =['id'])
print("\nThere are", len(notAllWomen.index), "tweets with the #NotAllWomen hashtag")

sexism = pd.concat([notallmen, notAllWomen], axis = 0)
print("\nThere are", len(sexism.index), "tweets total")
sexism = sexism.sample(frac=1)

tweet_ids = list(sexism['id'])

#Below works as long as it's not a multiple of 100. takes a while
results = lookup_tweets(tweet_ids, api)
# Out:
# There are 69873 tweets with the #NotAllMen hashtag
#
# There are 1827 tweets with the #NotAllWomen hashtag
#
# There are 71700 tweets total
#
# There are 71700 tweet IDs to fetch
# Fetching tweets...
# 20% complete
# 40% complete
# 60% complete
# 80% complete
# Around index: 71700
#  [{'code': 38, 'message': 'id parameter is missing.'}]
#
# There are 0 tweet IDs to fetch

# %%
temp = ""
final = pd.DataFrame() 
for i, obj in enumerate(results):
    
    temp = json.dumps([status._json for status in results[i]])#create JSON string
    temp_df = pd.read_json(temp, orient='records')
    temp_df = temp_df[['id','text']]
    final = final.append(temp_df, ignore_index = True)
    
pd.set_option('display.max_colwidth', -1)
print(final.info())
final.head()

final.dropna(inplace = True)
final.reset_index(drop=True, inplace = True)
final.drop_duplicates(subset='text',inplace =True ) #Important to drop duplicates

print("After Dropping nulls and duplicate tweets (such as retweets) there are",\
     len(final.index), "tweets")
final['text'] = final['text'].astype(str)
final['text'] = final['text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
final.to_csv('gs://csc3002/pretrain_data/tweetText/sexismTweets.csv', sep = ',', encoding='utf-8',\
              index = False, header = True)
final.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71700 entries, 0 to 71699
# Data columns (total 2 columns):
# id      71700 non-null int64
# text    40352 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.1+ MB
# None
# After Dropping nulls and duplicate tweets (such as retweets) there are 19030 tweets
#                        id  \
# 40330  471202846256668672
# 40338  475397749538848768
# 40339  471233196664053760
# 40341  473904513699835904
# 40347  470675133255139328
#
#                                                                                                                                                     text
# 40330  #YesAllWomen have had to define and defend feminism, even to #NotAllMen.
# 40338  @adkarabinus #notallmen need us but #yesallwomen do #imgoingtohellforsayingthat #shouldvetakenthepitch Still, we must  #feedBrendanBenson
# 40339  #YesAllWomen Is Brilliant Response 2 #NotAllMen http://t.co/9AvtGy6Z21 via @bustle #Feminism = #equality4all #StandWithWomen
# 40341  @MisterSchaffner I don't know if I hate it or #NotAllWomen more
# 40347  RT @JasonCarlen: I'm starting to think that the #NotAllMen and #YesAllWomen hashtag activism is the beginning of a gender war the likes we'\u2026

# %% [markdown]
# ## Large tweet datasets
#
# The next couple of cells are containing very large tweet ID datasets. I'm not sure if I'll be able to retrieve all of the tweets in one session as it takes so long, also converting a very large dataframe to a json via pandas throws a MemoryError
#
# I'll slightly alter the previous lookup_tweets function to checkpoint by saving the tweet text to a designated google bucket file path after however many IDs have been fetched
#
# These datasets - while they have a much larger volume than the others - have less desirable tweets to my pretraining than the other datasets. For one, these datasets are likely to have more non-user generated tweets and possibly spam as they're based on huge movements or global issues, unlike the niche subjects before.
#
# Also, the immigration executive order tweets are much more difficult to anticipate what common terms to remove from the tweets that might affect the learning of the word-masking task (for example in the #Chalkening tweets I'll remove #chalkening from each tweet because the model could just learn that #chalkening is likely to be the missing word in each sequence, just because it comes up in each tweet).
#
# Therefore, I'll not use all of the tweets from each of these sets, but rather a sample. Still, I might as well retrieve as many as I can, in case my strategy changes later and I find that the more tweets I do further pre-training on the better my model performs.

# %%
 def lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint = 500000):
    print("Saving tweet text in directory at path", dirc)
    full_tweets = []
    tweet_count = len(tweet_IDs)
    
    print("\nThere are", tweet_count, "tweet IDs to fetch")
    print("Checkpoint saved every", checkpoint, "IDs")
    
    if tweet_count < 1:
        return full_tweets
    
    #Below code to monitor progress
    #It's divided by 500 because we retrieve tweets via API call 100 at a time.
    #and we're looking to monitor progess each 5th of the way complete
    x = int(tweet_count/500) 
    progress = {x: '20%', x*2: '40%', x*3: '60%', x*4: '80%'}
    
    #Value for checkpoint saves. Dictates how many files there are
    ckpt = 5
    print("Fetching tweets...")
    try:
        for i in range((tweet_count // 100) + 1):
            if i in list(progress.keys()):
                print(progress[i], "complete")

        
            # Catch the last group if it is less than 100 tweets
            end_loc = min((i + 1) * 100, tweet_count)
            #It was .extend but it is slower than .append
            full_tweets.append(
                api.statuses_lookup(id_=tweet_IDs[i * 100:end_loc], map_ = True))
                
            #Checkpointing every time the tweet ID dataset reaches a multiple of 500,000
            if (i*100)%checkpoint == 0 and i != 0:
                    
                print("Checkpoint at tweet ID No.", i*100)
                temp = ""
                interim = pd.DataFrame() 
                for i, obj in enumerate(full_tweets):

                    temp = json.dumps([status._json for status in full_tweets[i]])#create JSON string
                    temp_df = pd.read_json(temp, orient='records')
                    temp_df = temp_df[['id','text']]
                    interim = interim.append(temp_df, ignore_index = True)

                

                interim.dropna(inplace = True)
                interim.reset_index(drop=True, inplace = True)
                interim.drop_duplicates(subset='text',inplace =True ) #Important to drop duplicates

                interim['text'] = interim['text'].astype(str)
                interim['text'] = interim['text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
                """"
                temp = json.dumps([status._json for status in full_tweets]) #create JSON
                interim = pd.read_json(temp, orient='records')
                interim = interim[['id','text']]
                interim.dropna(inplace = True)
                interim.reset_index(drop=True, inplace = True)
                
                interim.drop_duplicates(subset='text',inplace =True ) #Important to drop duplicates
                """
                path = dirc + '/' + str(ckpt) + '.csv'
                print("Saving at path", path)
                interim.to_csv(path, sep = ',', encoding='utf-8',\
                              index = False, header = True)
                ckpt = ckpt + 1
                full_tweets = [] # Reinitialise to empty dataframe
        
        
        #Outside of the loop
        print("Final save")
        temp = ""
        interim = pd.DataFrame() 
        for i, obj in enumerate(full_tweets):

            temp = json.dumps([status._json for status in full_tweets[i]])#create JSON string
            temp_df = pd.read_json(temp, orient='records')
            temp_df = temp_df[['id','text']]
            interim = interim.append(temp_df, ignore_index = True)



        interim.dropna(inplace = True)
        interim.reset_index(drop=True, inplace = True)
        interim.drop_duplicates(subset='text',inplace =True ) #Important to drop duplicates
        interim['text'] = interim['text'].astype(str)
        interim['text'] = interim['text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
        path = dirc + '/' + str(ckpt) + '.csv'
        print("Saving at path", path)
        interim['text'] = interim['text'].astype(str)
        interim['text'] = interim['text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
        interim.to_csv(path, sep = ',', encoding='utf-8',\
                      index = False, header = True)
        
# Keep this return statement in the case of an TweepError so it can be recursively called and continue the function
        return full_tweets 
    
    except tweepy.TweepError as e:
        print("Around index:", i*100, "\n", e.reason)       
        #Recursive call to continue even with exception
        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)

# %% [markdown]
# *   ### <b>#YesAllWomen Twitter IDs:</b>
#
# This hashtag was popular in May 2014, and was created partly in response to the Twitter hashtag #NotAllMen. #YesAllWomen reflected a grassroots campaign in which women shared their personal stories about harassment and discrimination. The campaign attempted to raise awareness of sexism that women experience, often from people they know.
#
# <b>There are around 2.7 million tweet IDs in this database</b>

# %%
yesAllWomen = pd.read_csv('gs://csc3002/pretrain_data/tweetIDs/YesAllWomen.ids.txt', sep=',',  index_col = False, header=None, names =['id'])
print("There are", len(yesAllWomen.index), "tweets with the #YesAllWomen hashtag")
tweet_ids = list(yesAllWomen['id'])

#Path to directory holding all saves
path = 'gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets' 
results = lookup_tweets_ckpt(tweet_ids[2000000:], api, path, checkpoint = 500000)
# Out:
# There are 2705985 tweets with the #YesAllWomen hashtag
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705985 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471518693134843904%2C471518697333338112%2C471518698369343488%2C471518701926490112%2C471518704753057792%2C471518705587732480%2C471518706040725505%2C471518707986878464%2C471518708809367552%2C471518710503849984%2C471518713137475584%2C471518714378977282%2C471518714584899584%2C471518716031942656%2C471518716568825856%2C471518718263328768%2C471518720482099200%2C471518723866918912%2C471518725410410496%2C471518725452345344%2C471518727729446912%2C471518729075826688%2C471518729616904192%2C471518730959466496%2C471518731433046016%2C471518731789934592%2C471518731802128385%2C471518733392166912%2C471518735011160064%2C471518738290728961%2C471518738723135489%2C471518739007954944%2C471518739201282048%2C471518739738152960%2C471518740308586496%2C471518741835309056%2C471518742284099585%2C471518744595144704%2C471518744658055168%2C471518746566066176%2C471518748219047936%2C471518748415770624%2C471518748805836800%2C471518750185766912%2C471518750882410496%2C471518751804776449%2C471518751813160960%2C471518753516433409%2C471518754296168449%2C471518754631712768%2C471518754833068032%2C471518756544339968%2C471518756649201664%2C471518757043834880%2C471518757311889409%2C471518757391572992%2C471518758528622592%2C471518758918303744%2C471518759254261760%2C471518759619145728%2C471518759669088256%2C471518760135041024%2C471518761179029504%2C471518761598865408%2C471518765151424512%2C471518766036049920%2C471518766317068288%2C471518767533412352%2C471518768905347072%2C471518769417031680%2C471518771673563136%2C471518772252381185%2C471518776094363648%2C471518776291123200%2C471518777390415872%2C471518777549402112%2C471518780154458112%2C471518784076152832%2C471518784189001729%2C471518785468633089%2C471518786622083072%2C471518787989028864%2C471518789872267265%2C471518790375989248%2C471518792065880064%2C471518792183721985%2C471518792489914368%2C471518793479782400%2C471518793756205056%2C471518794310238208%2C471518794834518017%2C471518795295514624%2C471518795593293824%2C471518797879193600%2C471518798630354944%2C471518799431475200%2C471518799536324609%2C471518800542961665%2C471518801205669888%2C471518801243418624&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000236D152FEB8>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705885 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471518802128420865%2C471518804166447104%2C471518806137794561%2C471518806364680192%2C471518808683724800%2C471518809661005825%2C471518810911305728%2C471518811904950273%2C471518812051750913%2C471518812781969408%2C471518814384168960%2C471518815315308544%2C471518817097502723%2C471518817189773312%2C471518818536521728%2C471518820855996416%2C471518822630195200%2C471518823850733570%2C471518824794042368%2C471518824974385154%2C471518827117682688%2C471518829097406466%2C471518830007574528%2C471518832646184960%2C471518833283301376%2C471518833618853888%2C471518836899201024%2C471518837318234112%2C471518837490204673%2C471518838530781184%2C471518839096627200%2C471518840174571521%2C471518840212303872%2C471518842930225152%2C471518844192698368%2C471518845455564800%2C471518846247907328%2C471518846520918016%2C471518847162679296%2C471518850165374977%2C471518850178375680%2C471518851126263808%2C471518853231824896%2C471518853642473472%2C471518854343299072%2C471518854922141696%2C471518856502988800%2C471518856876654592%2C471518858390810625%2C471518862907695104%2C471518864098869250%2C471518864590004226%2C471518864618950656%2C471518866560937984%2C471518868549021696%2C471518868561616896%2C471518869383680002%2C471518871375986688%2C471518871606661120%2C471518871770656768%2C471518873158549505%2C471518873528074240%2C471518873616146432%2C471518874035572736%2C471518874157203456%2C471518874165608448%2C471518875411312640%2C471518875503566850%2C471518876011073536%2C471518877047087104%2C471518879127064577%2C471518880385351680%2C471518880620232705%2C471518883959291906%2C471518883971866624%2C471518884642557953%2C471518884965527552%2C471518885078769665%2C471518885376569344%2C471518888664895489%2C471518889474420736%2C471518889575067648%2C471518897879801857%2C471518898995875840%2C471518899268497409%2C471518899301675008%2C471518906298167296%2C471518907010801664%2C471518907929337857%2C471518908797550592%2C471518908869275648%2C471518910916091904%2C471518911855226880%2C471518914355003392%2C471518914820997120%2C471518917551063040%2C471518918092525568%2C471518919665012736%2C471518920172523520%2C471518920419987456&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000234949CF160>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705785 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471518921648898048%2C471518921665683456%2C471518922521706496%2C471518923570294784%2C471518926032359425%2C471518926229102592%2C471518927067947008%2C471518931513913345%2C471518932700905472%2C471518933200015360%2C471518935083646976%2C471518936136429568%2C471518936824303616%2C471518937109520384%2C471518937197199360%2C471518937742467072%2C471518938019287040%2C471518938342256641%2C471518938653016064%2C471518938959208449%2C471518939353071616%2C471518939374043136%2C471518940431388672%2C471518940565221377%2C471518941261484032%2C471518942046220288%2C471518943195451392%2C471518943736520704%2C471518945229680641%2C471518946584043520%2C471518947401928704%2C471518949234847744%2C471518949554024448%2C471518949650071552%2C471518950308581377%2C471518950925533184%2C471518951961542656%2C471518952380964864%2C471518952410333184%2C471518952632619008%2C471518953005531136%2C471518954654285824%2C471518956080345088%2C471518958009323520%2C471518959440003072%2C471518959481929728%2C471518959959687169%2C471518961545125888%2C471518962249789440%2C471518962597896192%2C471518963835604992%2C471518966389964800%2C471518968902320128%2C471518969254264834%2C471518970097324032%2C471518974602412032%2C471518975101513728%2C471518976514592768%2C471518980599853056%2C471518981443297280%2C471518982059474944%2C471518982991003648%2C471518985255538688%2C471518986669400064%2C471518986736508928%2C471518986942025728%2C471518987008761857%2C471518987210489857%2C471518987658862592%2C471518988946522112%2C471518992029724672%2C471518992277204992%2C471518995326447616%2C471518997658480640%2C471518998329192448%2C471518998660911104%2C471518998665125888%2C471518999365566464%2C471518999743049728%2C471519001034502145%2C471519002305372161%2C471519002447978496%2C471519003798560768%2C471519006357475328%2C471519006365859840%2C471519006759723008%2C471519007414034432%2C471519008412692480%2C471519008504569856%2C471519008550690817%2C471519010459115520%2C471519011159953408%2C471519011214479360%2C471519017531084800%2C471519017924980739%2C471519017992089600%2C471519019732717568%2C471519020681023488%2C471519021645299712%2C471519021750181888&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237DA0B0940>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705685 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519022131843072%2C471519022471581696%2C471519023013060608%2C471519023167860737%2C471519024518791168%2C471519024527208448%2C471519024946618369%2C471519025122779136%2C471519026284208129%2C471519026829877248%2C471519027534110720%2C471519028499218432%2C471519028557918208%2C471519028893057024%2C471519031766155264%2C471519034572169216%2C471519036959113216%2C471519040473550848%2C471519041241112576%2C471519042360987649%2C471519043212808193%2C471519044802060289%2C471519044944674817%2C471519047167639552%2C471519047851724800%2C471519049374261248%2C471519050066329600%2C471519050343145472%2C471519050531880961%2C471519051706277888%2C471519052763250688%2C471519053689810944%2C471519054629732352%2C471519056609042432%2C471519056747429888%2C471519058102214657%2C471519058719150080%2C471519059285401600%2C471519059364696064%2C471519060682080256%2C471519063639064576%2C471519065823907840%2C471519066705113089%2C471519067413569536%2C471519071809601536%2C471519072048652288%2C471519073252417537%2C471519074040573953%2C471519074770358272%2C471519076435501056%2C471519076980781056%2C471519077677015040%2C471519078838837248%2C471519078935318528%2C471519079484764161%2C471519079610593280%2C471519080370155520%2C471519081259347968%2C471519081892704256%2C471519082005942272%2C471519082169532416%2C471519082857365504%2C471519083087683584%2C471519086623875072%2C471519088737783808%2C471519089127862272%2C471519089245323264%2C471519090322849792%2C471519092978233344%2C471519098439221248%2C471519098703060992%2C471519099592245248%2C471519100573728768%2C471519101131571200%2C471519102331125760%2C471519107397857280%2C471519112360103939%2C471519113345380352%2C471519113467424768%2C471519114079395840%2C471519118764433409%2C471519119746297856%2C471519120085630977%2C471519122254479360%2C471519122434830337%2C471519123638198273%2C471519124049231872%2C471519126994055169%2C471519127577059328%2C471519127622778880%2C471519128478814209%2C471519128809775104%2C471519129766477824%2C471519131326357504%2C471519131834265600%2C471519132429455361%2C471519132832501760%2C471519133020856321%2C471519134581530624%2C471519134896099328&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237DA0E58D0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705585 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519136972304385%2C471519137642971136%2C471519138373185536%2C471519138620272640%2C471519140046336000%2C471519142764625920%2C471519143192449024%2C471519145910358016%2C471519148967612416%2C471519157276901376%2C471519157352013824%2C471519157520171008%2C471519159696621568%2C471519161428893696%2C471519162875908097%2C471519163077234689%2C471519163303751680%2C471519167036669952%2C471519168122986496%2C471519169511309312%2C471519171293884416%2C471519172745105408%2C471519173013934081%2C471519175857668096%2C471519178680446976%2C471519179703468032%2C471519184170778624%2C471519184208543744%2C471519188289191937%2C471519190046998528%2C471519190512201728%2C471519191955439617%2C471519192588353536%2C471519195055017984%2C471519195222388736%2C471519198217117697%2C471519199039213569%2C471519199206993921%2C471519201136750593%2C471519201899720704%2C471519204793798656%2C471519205096194049%2C471519205263933440%2C471519206799069184%2C471519210644840449%2C471519213409304576%2C471519213463433218%2C471519216668274688%2C471519223072976896%2C471519223957561344%2C471519225090424832%2C471519228088950784%2C471519230006145024%2C471519231477944320%2C471519232124280832%2C471519233847734272%2C471519233856516096%2C471519234741133313%2C471519235215462401%2C471519235358093312%2C471519236351741953%2C471519237392330752%2C471519239443341312%2C471519239585533952%2C471519240684441600%2C471519240915525633%2C471519241208741888%2C471519241469186048%2C471519241774956544%2C471519242270302208%2C471519244530614273%2C471519246195773440%2C471519247022047232%2C471519247244357632%2C471519250340147200%2C471519250801496064%2C471519251950735360%2C471519254798692352%2C471519255972691970%2C471519256367349760%2C471519257537167360%2C471519260347740160%2C471519263258210305%2C471519263551795200%2C471519263614701568%2C471519264269021185%2C471519264445186048%2C471519266458451968%2C471519267939049473%2C471519270824714240%2C471519271039037441%2C471519271454277632%2C471519271785627649%2C471519275627577344%2C471519276038246400%2C471519276176666625%2C471519279070732288%2C471519279620562944%2C471519279683088384%2C471519280283258880&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237DA0E50F0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705485 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519281218609153%2C471519282766290944%2C471519284615987200%2C471519285467439104%2C471519286981570560%2C471519287426179072%2C471519290123112448%2C471519290605064192%2C471519290739281920%2C471519294254092288%2C471519295374372864%2C471519296783650816%2C471519297320550400%2C471519297399820288%2C471519297450147840%2C471519297672871936%2C471519298507116544%2C471519301296345089%2C471519301963218944%2C471519307516895232%2C471519308317618177%2C471519308552876032%2C471519309261709312%2C471519309718495232%2C471519311614705664%2C471519315712176128%2C471519318044581888%2C471519318476619777%2C471519320280170497%2C471519320972214272%2C471519322394066944%2C471519322532089856%2C471519322545070080%2C471519322964127746%2C471519324340244481%2C471519325958856705%2C471519326277627904%2C471519326348914688%2C471519327720837120%2C471519330199281664%2C471519330727776256%2C471519331679866881%2C471519332904620032%2C471519332954947584%2C471519333093756928%2C471519333735481344%2C471519336080101376%2C471519336201334784%2C471519340010172416%2C471519341507538945%2C471519342019219457%2C471519344586129408%2C471519346917793792%2C471519349233422336%2C471519349405409280%2C471519350449766400%2C471519351116664832%2C471519351305027584%2C471519351334391808%2C471519353309892608%2C471519353817812993%2C471519355931729920%2C471519357852348418%2C471519360746409984%2C471519362646818816%2C471519364160950273%2C471519364747771904%2C471519365821902848%2C471519366085763073%2C471519367315066880%2C471519370049757184%2C471519370364338176%2C471519370649161728%2C471519372863758337%2C471519373266808833%2C471519373463924736%2C471519376332840960%2C471519376899059712%2C471519377393582081%2C471519380400914432%2C471519380975538177%2C471519381147881473%2C471519383769346049%2C471519384339759104%2C471519384565858304%2C471519385962573825%2C471519386772045824%2C471519388093276160%2C471519388378873856%2C471519389297430528%2C471519390014271488%2C471519394057977857%2C471519395806580737%2C471519395995725826%2C471519396046069760%2C471519397949874176%2C471519398935535616%2C471519401460518912%2C471519402299379712%2C471519403239276544&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237DA0E6470>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705385 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519403369304064%2C471519404929200128%2C471519405235773440%2C471519405755478016%2C471519406955048962%2C471519409605853185%2C471519412910968832%2C471519413360160768%2C471519413938561024%2C471519414085746688%2C471519416761339904%2C471519417117843456%2C471519417252474880%2C471519417860255744%2C471519418996899840%2C471519421140172800%2C471519423174418432%2C471519423442870272%2C471519426698051584%2C471519426785710081%2C471519426819657728%2C471519429948604416%2C471519430271197184%2C471519431055933441%2C471519431345311744%2C471519433182044161%2C471519434863947776%2C471519435728359424%2C471519435950260224%2C471519436482961409%2C471519436625952769%2C471519436781142016%2C471519437645185024%2C471519438299492352%2C471519439553585152%2C471519440065273856%2C471519440358883328%2C471519442279473155%2C471519443487825920%2C471519444624482304%2C471519445920137217%2C471519446495145984%2C471519447426293760%2C471519447945990145%2C471519448822980608%2C471519449015521280%2C471519449158127617%2C471519452186820608%2C471519452886876160%2C471519454409785344%2C471519456015810560%2C471519457378963456%2C471519457505206272%2C471519458054250496%2C471519458226610176%2C471519459359088640%2C471519459400638465%2C471519460172787712%2C471519460436623362%2C471519460952928256%2C471519464799100928%2C471519465025589249%2C471519468435144704%2C471519468783300608%2C471519469773520896%2C471519470583054336%2C471519472117764096%2C471519472960823297%2C471519473447342080%2C471519474609553408%2C471519474982850560%2C471519478749356032%2C471519479676305408%2C471519480586051586%2C471519482783879168%2C471519483618549760%2C471519484948131840%2C471519490664968192%2C471519491953029120%2C471519491986178048%2C471519492439539712%2C471519492489490432%2C471519492577583104%2C471519494444052481%2C471519494540886016%2C471519497346486273%2C471519499275874304%2C471519499686916098%2C471519499813158912%2C471519505923862528%2C471519509103136768%2C471519509875273728%2C471519511880159232%2C471519512807100416%2C471519514559913984%2C471519515826987008%2C471519516737163265%2C471519517123018752%2C471519518632972288%2C471519518712279041&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237DA0E6DA0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705285 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519518754230272%2C471519519614464001%2C471519519622430720%2C471519520151326721%2C471519524333047809%2C471519525318299648%2C471519525541011456%2C471519525855563776%2C471519527667499009%2C471519527885230080%2C471519528728678401%2C471519535644672000%2C471519536051912705%2C471519537721253888%2C471519538056396800%2C471519542137475072%2C471519542158430208%2C471519542183997440%2C471519542879846400%2C471519543631020032%2C471519544985804801%2C471519545081872384%2C471519546059550720%2C471519546860261376%2C471519548575711232%2C471519549092032512%2C471519549679222784%2C471519550668689409%2C471519551528906752%2C471519552216776704%2C471519555266039808%2C471519558751100929%2C471519558985990144%2C471519560034570240%2C471519563390398465%2C471519564082065408%2C471519564518273026%2C471519568993587201%2C471519571019857922%2C471519571187621891%2C471519572139712513%2C471519575666749441%2C471519577571356672%2C471519578309132288%2C471519579395870720%2C471519580402098177%2C471519580406288384%2C471519583082643456%2C471519584416432128%2C471519584710033408%2C471519585624399872%2C471519586399952896%2C471519586488422400%2C471519591890694144%2C471519592913727488%2C471519594666926080%2C471519594688294912%2C471519595934019584%2C471519596193660928%2C471519596747685888%2C471519597364277250%2C471519597808480256%2C471519597838233600%2C471519600492806144%2C471519601637855232%2C471519603244695552%2C471519603412045824%2C471519605140107264%2C471519607476727808%2C471519607501516801%2C471519607686041601%2C471519607711629312%2C471519609825132544%2C471519611825836032%2C471519613130256384%2C471519613780385792%2C471519617169371136%2C471519619195232256%2C471519619551744000%2C471519621128785921%2C471519622286802945%2C471519622961704960%2C471519625163726848%2C471519625750925312%2C471519626757558272%2C471519626762133504%2C471519627256676352%2C471519628066553856%2C471519628339212288%2C471519628464640000%2C471519630268178432%2C471519631690067968%2C471519631706836994%2C471519633393336321%2C471519633434894336%2C471519634051440640%2C471519635053883392%2C471519635586572288%2C471519637315006464%2C471519638703321089&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237DA0FDEF0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705185 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519639617277952%2C471519640003153920%2C471519640120987648%2C471519641517301760%2C471519642712694784%2C471519644172685312%2C471519645246029824%2C471519646685085696%2C471519646974083072%2C471519647250935808%2C471519647766827008%2C471519648316264448%2C471519650304389120%2C471519651273637888%2C471519652766433280%2C471519652766814208%2C471519652904841216%2C471519653705965568%2C471519654645866496%2C471519654851403776%2C471519656378130433%2C471519657858314240%2C471519658047438848%2C471519659976425472%2C471519660073304064%2C471519660132012034%2C471519661037985793%2C471519661184778240%2C471519662841528321%2C471519663604912128%2C471519665882021888%2C471519667928846336%2C471519669044514816%2C471519669665673216%2C471519670118260737%2C471519673385631744%2C471519673905709056%2C471519674845233153%2C471519675218550784%2C471519675428655105%2C471519676304859136%2C471519676926001152%2C471519677798436864%2C471519677894897664%2C471519678301351936%2C471519680751230976%2C471519684370505728%2C471519685591064576%2C471519686690353153%2C471519687331696640%2C471519687918882816%2C471519689923772416%2C471519693002387457%2C471519696286527488%2C471519697306128384%2C471519698061127680%2C471519699671740416%2C471519699776577537%2C471519700803788800%2C471519702968467456%2C471519706588147713%2C471519707569614848%2C471519707728990209%2C471519708593025024%2C471519708723044352%2C471519709876084736%2C471519709926797312%2C471519710056820736%2C471519711641886720%2C471519716456931328%2C471519717858213888%2C471519718705475584%2C471519719011258368%2C471519720563548160%2C471519722249650176%2C471519723847680000%2C471519724719702017%2C471519725415968769%2C471519725868961792%2C471519726523654144%2C471519726691045377%2C471519727420846081%2C471519728427470848%2C471519730160132096%2C471519730835410944%2C471519730939867136%2C471519731048931328%2C471519731565215744%2C471519733662359553%2C471519737764397056%2C471519740523864064%2C471519741866037249%2C471519742428069888%2C471519743652794368%2C471519745284800512%2C471519745456762880%2C471519748128133120%2C471519749508038656%2C471519749525241856%2C471519751764967424&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237DF788278>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 705085 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519755120414721%2C471519755313356800%2C471519755405250560%2C471519756462194688%2C471519758563958784%2C471519758718758912%2C471519760446808065%2C471519761223143425%2C471519761680318464%2C471519763387006977%2C471519763580338176%2C471519764712402944%2C471519766083940352%2C471519766155624448%2C471519766231121921%2C471519766515965952%2C471519766989922305%2C471519767820783616%2C471519768118169600%2C471519769125208064%2C471519769581985792%2C471519769791705088%2C471519770618372096%2C471519771486593025%2C471519772220612608%2C471519772236984320%2C471519772241178624%2C471519772925239296%2C471519775563460608%2C471519776494592001%2C471519779455377408%2C471519781976162305%2C471519784203333632%2C471519784232706048%2C471519785771991040%2C471519787852763136%2C471519789492355072%2C471519789752799232%2C471519790289281024%2C471519791501832192%2C471519793108246528%2C471519793292390400%2C471519800498614272%2C471519800897052673%2C471519801173487616%2C471519801383202816%2C471519801970798592%2C471519802133979136%2C471519803249664001%2C471519804843888640%2C471519805002874881%2C471519805325844480%2C471519806538383360%2C471519809515974658%2C471519813064335360%2C471519813312184320%2C471519815174475776%2C471519817749782528%2C471519818349178880%2C471519818676719616%2C471519821218070528%2C471519822275440640%2C471519824611254272%2C471519824867098624%2C471519828230942720%2C471519828478808064%2C471519829396955136%2C471519829430501376%2C471519830139338752%2C471519832215924736%2C471519832362323968%2C471519834476642305%2C471519834589913088%2C471519834862518272%2C471519836259246080%2C471519836393459712%2C471519837475577856%2C471519839765684224%2C471519840121806849%2C471519840776515584%2C471519841178746880%2C471519841330143232%2C471519841812504576%2C471519843003695104%2C471519843137486849%2C471519845084057600%2C471519846232907776%2C471519847403495424%2C471519847977713665%2C471519849005330432%2C471519849433530368%2C471519849655435264%2C471519850943504386%2C471519851081916416%2C471519851560071168%2C471519852700897280%2C471519852738641920%2C471519854059479041%2C471519854596333568%2C471519855296798720&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237DF788A58>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 704985 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519855745581056%2C471519856433852416%2C471519856719069184%2C471519860103454720%2C471519860162166785%2C471519861026201601%2C471519861697691650%2C471519861726658560%2C471519863383408640%2C471519864310730752%2C471519865174765568%2C471519865426440193%2C471519866152042496%2C471519866386927616%2C471519866508177408%2C471519866839511040%2C471519869297782784%2C471519871483015168%2C471519871503593472%2C471519872334049280%2C471519874158563328%2C471519874934513664%2C471519875668516867%2C471519876268306434%2C471519878860402688%2C471519880433655808%2C471519883101216768%2C471519883629297664%2C471519883952656384%2C471519885277679616%2C471519885286072320%2C471519885441646592%2C471519885714280449%2C471519886611464193%2C471519889320988672%2C471519890894237697%2C471519892470898688%2C471519892705771520%2C471519894211932160%2C471519894417063936%2C471519895193022464%2C471519897902923776%2C471519898833661952%2C471519900867915776%2C471519901010890752%2C471519901115367424%2C471519901622865920%2C471519902436569088%2C471519905519378434%2C471519907343917056%2C471519907390455808%2C471519907847208961%2C471519915875115009%2C471519916000952320%2C471519920123961345%2C471519921524850688%2C471519922624135168%2C471519923366535168%2C471519925383598080%2C471519926507667456%2C471519929326260224%2C471519932815921152%2C471519933910622209%2C471519935026712576%2C471519936217509889%2C471519937589026817%2C471519938356580354%2C471519938453438464%2C471519942026985475%2C471519943075196929%2C471519943260110848%2C471519943276916736%2C471519943284899840%2C471519943419117569%2C471519944627077120%2C471519946321567744%2C471519946728419330%2C471519949198852096%2C471519949274771456%2C471519954618318848%2C471519954647281664%2C471519955113230336%2C471519959613722624%2C471519960125018114%2C471519960628355072%2C471519960968474624%2C471519961748627456%2C471519962167664640%2C471519964265201665%2C471519965250469888%2C471519965380870144%2C471519965561257984%2C471519965586411520%2C471519966433255424%2C471519967389949952%2C471519972305276928%2C471519972611874816%2C471519973089607680%2C471519975573041152%2C471519976671559680&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000237D9F39400>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 704885 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471519978135773184%2C471519978194485248%2C471519978680627200%2C471519979637334016%2C471519979708243968%2C471519981080178689%2C471519981360787456%2C471519982229000192%2C471519985526132736%2C471519987677396992%2C471519989246472192%2C471519992412782592%2C471519993469751296%2C471519993603977216%2C471519993859825664%2C471519995667968000%2C471519997668237312%2C471520001896091648%2C471520001904902145%2C471520002315915264%2C471520004039794688%2C471520007529050113%2C471520012419604480%2C471520012755140608%2C471520014046990336%2C471520015246557184%2C471520015686983680%2C471520016269979650%2C471520019604439040%2C471520020645031936%2C471520020762079232%2C471520024390533120%2C471520025187475456%2C471520025749491712%2C471520026663477249%2C471520027183951872%2C471520027678486528%2C471520028094107648%2C471520028840321024%2C471520030027681792%2C471520031244054528%2C471520032636162048%2C471520032954933248%2C471520033475407873%2C471520033521565696%2C471520033773195264%2C471520034045452288%2C471520035006320640%2C471520036293971969%2C471520036301967360%2C471520036956680193%2C471520037564870656%2C471520037828694016%2C471520038101716992%2C471520038256918528%2C471520038386556928%2C471520038961176576%2C471520041629130752%2C471520043000287232%2C471520047350161408%2C471520048159272961%2C471520048226791424%2C471520050026147840%2C471520050537447425%2C471520050814652416%2C471520052198772736%2C471520052312014848%2C471520052395528192%2C471520053125337088%2C471520053356003328%2C471520053507014656%2C471520053641228288%2C471520053712535552%2C471520056191746048%2C471520059480109056%2C471520059874353152%2C471520061438828544%2C471520064446160896%2C471520064462934016%2C471520064974245888%2C471520064995598336%2C471520069768712192%2C471520070372708352%2C471520070406262784%2C471520070733418496%2C471520072163262464%2C471520072184250369%2C471520074310750209%2C471520074629914624%2C471520076844503040%2C471520078597332992%2C471520081105936385%2C471520082049642496%2C471520083299536896%2C471520085773787136%2C471520086571089920%2C471520086701113345%2C471520087556382720%2C471520088110432256%2C471520089708449792&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000236D15C39B0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 704785 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471520093361672192%2C471520093424197632%2C471520096041852928%2C471520096779657216%2C471520098931326976%2C471520098969071616%2C471520102098411520%2C471520103159566336%2C471520105809993728%2C471520105948401664%2C471520106351038464%2C471520106670219265%2C471520106950848512%2C471520107198705664%2C471520108108464128%2C471520108397875200%2C471520109207764992%2C471520109337780224%2C471520109375537152%2C471520111392595968%2C471520112004960256%2C471520112827064320%2C471520113330376704%2C471520113762795520%2C471520115230797824%2C471520115239157760%2C471520115440103424%2C471520115482054657%2C471520116304125952%2C471520116459716608%2C471520116619083776%2C471520117218492417%2C471520117503709185%2C471520118854664192%2C471520119122694144%2C471520119919628288%2C471520120141934592%2C471520123854270464%2C471520125955211264%2C471520126337310721%2C471520126450147328%2C471520127029346304%2C471520127410663424%2C471520128488587265%2C471520130149916673%2C471520130619297792%2C471520133073338369%2C471520136781103105%2C471520137623781376%2C471520137799954432%2C471520139112755200%2C471520140237225984%2C471520140421386240%2C471520141365108736%2C471520144393388032%2C471520144616067072%2C471520144854765568%2C471520145752350720%2C471520148621631488%2C471520148944216065%2C471520149364039682%2C471520152123494400%2C471520152756822016%2C471520153193443328%2C471520155164372992%2C471520156242288641%2C471520158184652800%2C471520158708555777%2C471520159078031360%2C471520159618719746%2C471520159765512193%2C471520161359351810%2C471520162446049280%2C471520166203756544%2C471520167122714624%2C471520168582344704%2C471520168791662592%2C471520169756352513%2C471520170091876352%2C471520174084874240%2C471520176744443904%2C471520176987316224%2C471520177079992320%2C471520178392793088%2C471520182238588928%2C471520183224631296%2C471520184722001920%2C471520185128452098%2C471520186018058240%2C471520186407743488%2C471520189725835265%2C471520189847453696%2C471520190702682113%2C471520193101836288%2C471520193785892864%2C471520194683469824%2C471520195463241728%2C471520196792836096%2C471520198357712896%2C471520200568098816&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000236D15C3FD0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 704685 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471520200592867328%2C471520201687965696%2C471520202027307008%2C471520202698412032%2C471520205529575425%2C471520205999710208%2C471520207312539648%2C471520209472208897%2C471520210021658624%2C471520210747674625%2C471520210978344960%2C471520212009766912%2C471520212387639296%2C471520212723200000%2C471520213058744320%2C471520214853885952%2C471520218423246848%2C471520218578055169%2C471520219001671680%2C471520219182419968%2C471520220624863233%2C471520221392805890%2C471520222311358464%2C471520222768558080%2C471520224420700160%2C471520224848904192%2C471520226191106048%2C471520226295562240%2C471520228044578816%2C471520230347640832%2C471520230410170368%2C471520232884809728%2C471520233992499200%2C471520234763874304%2C471520237029195776%2C471520237418868736%2C471520239252148224%2C471520239654420480%2C471520239989964801%2C471520241168973824%2C471520242934775808%2C471520244092399616%2C471520246549868544%2C471520247158013953%2C471520247296434176%2C471520248248942592%2C471520249662431232%2C471520251277234176%2C471520252723863552%2C471520253781221376%2C471520254628085760%2C471520254808850432%2C471520256041967616%2C471520256213540864%2C471520258956615680%2C471520259426377728%2C471520259568975872%2C471520259628081153%2C471520260281991168%2C471520261204758528%2C471520264853790720%2C471520265789534208%2C471520274110631938%2C471520274618138624%2C471520275230883840%2C471520276828930048%2C471520277445496834%2C471520277927837696%2C471520282512220161%2C471520282545356800%2C471520284160192512%2C471520284508307456%2C471520285301030912%2C471520285519138816%2C471520285934366720%2C471520286055997440%2C471520288367472640%2C471520290346778625%2C471520292616306688%2C471520293144379392%2C471520294017175552%2C471520295837523968%2C471520298337312768%2C471520299091894272%2C471520299809529856%2C471520301504032769%2C471520301818191872%2C471520302032105474%2C471520302220849152%2C471520303395651584%2C471520303974080512%2C471520304054140928%2C471520304616185856%2C471520304833916928%2C471520305240756225%2C471520305488211968%2C471520308591996928%2C471520309104111616%2C471520309443432449%2C471520309599023105&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000236D15EA7F0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 704585 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471520309858668544%2C471520310278512640%2C471520311931060224%2C471520312962461698%2C471520315592671232%2C471520316074631170%2C471520317912133632%2C471520319199399936%2C471520319211974656%2C471520320474869760%2C471520321032691712%2C471520322022559744%2C471520322177359872%2C471520323175981056%2C471520324602044417%2C471520325771857920%2C471520325990359040%2C471520327269634048%2C471520331912720385%2C471520331920719872%2C471520333908832256%2C471520333971738624%2C471520334005301248%2C471520335305515008%2C471520337948340224%2C471520338309050368%2C471520343551524865%2C471520344675598336%2C471520346315952128%2C471520348635004928%2C471520349243592704%2C471520349385793536%2C471520358097764352%2C471520358458093568%2C471520358747488256%2C471520360895381504%2C471520361268674560%2C471520361792557056%2C471520362811760640%2C471520363285737472%2C471520363348652032%2C471520365265444864%2C471520365941129217%2C471520366083719168%2C471520366183976961%2C471520366506962944%2C471520367308062720%2C471520368788639744%2C471520369602347008%2C471520370881597440%2C471520375231107072%2C471520378548801537%2C471520379056717824%2C471520380256280576%2C471520380839297025%2C471520381032230912%2C471520381669740544%2C471520381736464384%2C471520382114365440%2C471520382336266240%2C471520384421203968%2C471520384601174016%2C471520388405792768%2C471520390502555648%2C471520393144958977%2C471520393690238977%2C471520397276745728%2C471520403228073984%2C471520403324555264%2C471520403890794496%2C471520404067340288%2C471520404738015232%2C471520405966970880%2C471520406860345344%2C471520407397232640%2C471520408563245056%2C471520409632772096%2C471520409788358656%2C471520410027442176%2C471520411315097600%2C471520412010958848%2C471520413210923008%2C471520413311180801%2C471520414758621184%2C471520415760646144%2C471520416444342272%2C471520416733753344%2C471520418059538432%2C471520418990682112%2C471520420873916416%2C471520421670420480%2C471520422895161345%2C471520422949711873%2C471520423784353793%2C471520425189457920%2C471520426410381314%2C471520427693449216%2C471520428419063808%2C471520431871377408%2C471520432353730560&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000236D15F3080>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 704485 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471520432437592064%2C471520432932147202%2C471520435922681856%2C471520440590929920%2C471520440847179776%2C471520441535049728%2C471520441937723393%2C471520442558455808%2C471520442612609024%2C471520445930274816%2C471520448245948417%2C471520449671999488%2C471520449932054528%2C471520451336753153%2C471520452171816960%2C471520457078747136%2C471520457905033216%2C471520459885117440%2C471520460438773760%2C471520462150053889%2C471520462716272642%2C471520462908841984%2C471520463357620224%2C471520463752278016%2C471520463941029888%2C471520464775303168%2C471520465551634433%2C471520465769746433%2C471520465962663936%2C471520466092322817%2C471520467778805760%2C471520469883953152%2C471520471830515712%2C471520472513789952%2C471520476536139777%2C471520477052010496%2C471520477685374977%2C471520480235888641%2C471520483368656896%2C471520483868180481%2C471520483968446464%2C471520484035555329%2C471520485323194368%2C471520486170435584%2C471520486628007936%2C471520487336869888%2C471520488385040384%2C471520488528039937%2C471520489207529472%2C471520490645766144%2C471520491094568960%2C471520491719499777%2C471520492830986240%2C471520495922581504%2C471520497293746178%2C471520499080892416%2C471520500465041408%2C471520501383172096%2C471520502289555456%2C471520502868357120%2C471520503501701120%2C471520503828844545%2C471520508664483841%2C471520509981888512%2C471520512397824000%2C471520515518394369%2C471520516562354176%2C471520518055948288%2C471520518336569345%2C471520521436532736%2C471520524657381376%2C471520526016712704%2C471520527925137408%2C471520529468235776%2C471520530575949824%2C471520531108614144%2C471520533297635329%2C471520534401150976%2C471520535084802049%2C471520535617101824%2C471520536393437184%2C471520537039343616%2C471520537408450561%2C471520539304296449%2C471520539664977920%2C471520539765653506%2C471520539975385088%2C471520541413621760%2C471520543804387328%2C471520545012719617%2C471520547898019840%2C471520553270919168%2C471520553518768128%2C471520555271991296%2C471520556152401920%2C471520556152811520%2C471520556404072448%2C471520557339770880%2C471520559709175810%2C471520562208964609&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000236D15F3B70>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 704385 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
#  Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=471520563056623617%2C471520563601891328%2C471520564268371969%2C471520564637859840%2C471520570278817792%2C471520570450784257%2C471520570707046400%2C471520572263108608%2C471520573189656576%2C471520575509512193%2C471520579473129472%2C471520579494084608%2C471520580009996288%2C471520580274225153%2C471520580940738560%2C471520585130844161%2C471520585143439360%2C471520586381144066%2C471520586821558272%2C471520589547839488%2C471520594803326977%2C471520595881230336%2C471520596070002688%2C471520596770451457%2C471520597693169664%2C471520598070689792%2C471520598179328000%2C471520598422605824%2C471520598728781827%2C471520598926319616%2C471520600427859968%2C471520600993718273%2C471520601115336705%2C471520605016031232%2C471520606178258944%2C471520606337662976%2C471520606442098688%2C471520607566585856%2C471520607939489792%2C471520608212516864%2C471520609764409344%2C471520614306832384%2C471520615359582208%2C471520615472459776%2C471520615661588480%2C471520616604897280%2C471520617674838016%2C471520618232680449%2C471520622800281601%2C471520625392369664%2C471520625719115776%2C471520626012745729%2C471520630257758208%2C471520631742152704%2C471520632128028672%2C471520635206647808%2C471520636477526017%2C471520637157380097%2C471520638017220608%2C471520638822531072%2C471520642555465728%2C471520645700784128%2C471520650973429760%2C471520651291791360%2C471520653971972096%2C471520654878339072%2C471520654941253632%2C471520658246344704%2C471520658308857856%2C471520658548338688%2C471520658971951104%2C471520659190075392%2C471520659256774656%2C471520660918112256%2C471520661123661824%2C471520661836275712%2C471520664063868928%2C471520665057918976%2C471520666508734464%2C471520667469221888%2C471520667515752448%2C471520670090686464%2C471520670287810560%2C471520670749564928%2C471520672007475201%2C471520674029113344%2C471520676369551360%2C471520677078368256%2C471520678622269440%2C471520682317074432%2C471520684296785920%2C471520684519481344%2C471520685064323072%2C471520685370507265%2C471520685727424512%2C471520688470499328%2C471520689053118464%2C471520690663743488%2C471520690768584704%2C471520694019162112&map=True (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000235C8092400>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',)))
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets
#
# There are 704285 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Around index: 0
# ...
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-cf2347a0b6ba> in <module>
#       5 #Path to directory holding all saves
#       6 path = 'gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets'
# ----> 7 results = lookup_tweets_ckpt(tweet_ids[2000000:], api, path, checkpoint = 500000)
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#     100        print("Around index:", i*100, "\n", e.reason)
#     101        #Recursive call to continue even with exception
# --> 102        return full_tweets + lookup_tweets_ckpt(tweet_IDs[(i+1)*100:tweet_count], api, dirc, checkpoint)
#     103
#     104
#
# <ipython-input-14-771c2c3a9160> in lookup_tweets_ckpt(tweet_IDs, api, dirc, checkpoint)
#      29            #It was .extend but it is slower than .append
#      30            full_tweets.append(
# ---> 31                api.statuses_lookup(id_=tweet_IDs[i * 100:end_loc], map_ = True))
#      32
#      33            #Checkpointing every time the tweet ID dataset reaches a multiple of 500,000
#
# ~\Anaconda3\lib\site-packages\tweepy\api.py in statuses_lookup(self, id_, include_entities, trim_user, map_, tweet_mode)
#      95                         trim_user=None, map_=None, tweet_mode=None):
#      96         return self._statuses_lookup(list_to_csv(id_), include_entities,
# ---> 97                                      trim_user, map_, tweet_mode)
#      98
#      99     @property
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     660             )
#     661             if is_new_proxy_conn:
# --> 662                 self._prepare_proxy(conn)
#     663
#     664             # Make the request on the httplib connection object.
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     946         """
#     947         conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> 948         conn.connect()
#     949
#     950     def _new_conn(self):
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     332     def connect(self):
#     333         # Add certificate verification
# --> 334         conn = self._new_conn()
#     335         hostname = self.host
#     336
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     155         try:
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#     159
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:

# %% [markdown]
# <i>I fetched the first 2 million of these tweets in an unsupervised jupyter notebook session. We can combine all of the tweet text files into one csv and view how many tweets we have fetched overall after dropping duplicates and nans<i>

# %%
wom = pd.read_csv('gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets/1.csv', sep=',',  index_col = False, header=0)
wom2 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets/2.csv', sep=',',  index_col = False, header=0)
wom3 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets/3.csv', sep=',',  index_col = False, header=0)
wom4 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets/4.csv', sep=',',  index_col = False, header=0)
wom5 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets/5.csv', sep=',',  index_col = False, header=0)
wom6 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets/6.csv', sep=',',  index_col = False, header=0)

womTweets = pd.concat([wom, wom2, wom3, wom4, wom5, wom6], axis =0)
womTweets.drop_duplicates(subset='text',inplace =True )
womTweets.dropna(inplace = True)
print("\nThere are", len(womTweets.index), "unique tweets in this csv file after dropping duplicates over the entire database")
womTweets.to_csv('gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets.csv', sep = ',', \
                 encoding='utf-8', index = False, header = 0)
womTweets.head(50)
# Out:
# There are 388799 unique tweets in this csv file after dropping duplicates over the entire database
#                     id  \
# 0   470315730706399232
# 1   470317902776647680
# 2   470317461024555009
# 3   470316502445744130
# 4   470317309022978048
# 5   470315790885863424
# 6   470315890060189696
# 7   470316527959670784
# 8   470314968492302338
# 9   470315514980757504
# 10  470317132408823808
# 11  470315803863449602
# 12  470317538673721344
# 13  470317722770083840
# 14  470316458011262976
# 15  470319141589504000
# 16  470318781861216256
# 17  470319532402167808
# 18  470318362145615872
# 19  470318703054450688
# 20  470319530175385600
# 21  470318303068839936
# 22  470319466317099008
# 23  470319294916485120
# 24  470318256805670912
# 25  470318986006396928
# 26  470318196881625088
# 27  470319246657204224
# 28  470319494594703360
# 29  470319423778488321
# 30  470319236343406595
# 31  470318640089153537
# 32  470319403780038656
# 33  470318260542771201
# 34  470319529923325952
# 35  470318273406709760
# 36  470318694686797824
# 37  470318963914973184
# 38  470318418176901120
# 39  470318901193347074
# 40  470319191015571456
# 41  470318297175818240
# 42  470318533990449153
# 43  470318184923283456
# 44  470321125172736000
# 45  470320925788098560
# 46  470320078526111744
# 47  470321138242162688
# 48  470321038107357185
# 49  470320736523919361
#
#                                                                                                                                             text
# 0   because i get in an elevator with a guy and think "what's my escape plan going to be?" #yesallwomen
# 1   because it starts earlyschool dress codes punish girls for wearing clothes that are "distracting" to boys. #yesallwomen
# 2   because "boys will be boys" is a phrase that still exists. #yesallwomen
# 3   because we're taught "never leave your drink alone," instead of "don't drug someone." #yesallwomen
# 4   #yesallwomen have the right to set boundaries. prevalent misogyny has led to the extinction of private space for women.
# 5   because women are taught to carry our keys like a weapon in case we're attacked in a parking lot. #yesallwomen
# 6   hell yeah. #yesallwomen deserve the right to say no to a man without a given reason. they owe you
# 7   because there is a moment, daily, weekly, monthly, where you're in a situation where you think: "is today the day i get rap
# 8   sounds like something that needs to get shared right now. #yesallwomen
# 9   hell yeah. #yesallwomen deserve the right to say no to a man without a given reason. they owe you nothing!
# 10  #yesallwomen have had a man completely ignore the words coming out of her mouth, and look for secret signs that she's really interested.
# 11  because when i was dating, i'd spend more time setting up contingency plans "in case" with friends than doing my makeup. #yesallwomen
# 12  because we're taught that when we're walking by ourselves we need to look around us for safety. we can't simply walk #yesallwomen
# 13  #yesallwomen can wear whatever they want. nobody's "asking for it", be they clad in a bikini, pyjamas, dress or nothing at all.
# 14  because there is a moment, daily, weekly, monthly, where you're in a situation where you think: "is today the day i get raped?" #yesallwomen
# 15  because when having a first date, men worry women won't like themwomen worry what will happen if men like them too much. #yes
# 16  because nothing a woman wears or looks like or acts like means she owes you anything, especially sex. #yesallwomen
# 17  because you get to a point where you can't remember not being aware, alert, poised, keys between your knuckles. #yesallwomen
# 18  #yesallwomen have had to walk a little faster when a cat-caller gets too aggressive and won't back down.
# 19  many thanks to for bringing and #yesallwomen to my attention today. powerful truths that need to be spoken and heard.
# 20  because i wore a fake wedding ring when i waitressed. "belonging" to another man was the only way to get customers to back
# 21  because i wore a fake wedding ring when i waitressed. "belonging" to another man was the only way to get customers to back off. #yesallwomen
# 22  #yesallwomen start looking for an escape plan when they show disinterest in men and men hound on. because we are afrai
# 23  because sometimes even saying i'm happily married isn't enough and i have to flash my wedding ring. #yesallwomen
# 24  #yesallwomen have had a man completely ignore the words coming out of her mouth, and look for secret signs that she's
# 25  because when having a first date, men worry women won't like themwomen worry what will happen if men like them too much. #yesallwomen
# 26  because we're taught that when we're walking by ourselves we need to look around us for safety. we can't simply walk #
# 27  #yesallwomen know women who never reported being assaulted because they didn't have overwhelming evidence to prove it.
# 28  because we have to tell our friends and loved ones "call me when you get home" in case of assault. #yesallwomen
# 29  because i'm expected to take it as a compliment when some jerk says he'd still do me even though i'm pretty ugly. #yesallwomen
# 30  because when i say "no thanks, i'm married," i always have to say it again, and include the word "happily". #yesallwomen
# 31  #yesallwomen have learned that "i have a boyfriend" is the only way to possibly get a dude to back off, men respect other guy's property
# 32  #yesallwomen or because they were afraid they wouldn't be taken seriously
# 33  because women who get nervous when honked at just for walking down the street are "overreacting." #yesallwomen
# 34  #yesallwomen have crossed the street and/or avoided eye contact when a male is approaching them
# 35  #yesallwomen start looking for an escape plan when they show disinterest in men and men hound on. because we are afraid we might get hurt
# 36  because boys slap random girls' butts in halls of my daughter's high school, and no teacher, administrator, etc. says a thing. #yesallwomen
# 37  guys, please follow the #yesallwomen hashtag. read. learn. feel sickened. and more importantly, feel responsible.
# 38  because elliot rodgers. #yesallwomen
# 39  i really hate women. #yesallwomen
# 40  we've had several local cases involving men with opas against them who still get guns and kill their spouses. #yesallwomen
# 41  because we all have mothers and sisters and friends who we love and violence against women still happens all the time. #yesallwomen
# 42  because i was five when my parents signed me up for karate classes so i'd know how to defend myself. #yesallwomen
# 43  #yesallwomen have learned how to defend themselves with their keys if they are assaulted in a parking lot.
# 44  because rape is blamed on alcohol, clothes, being too friendly or too pretty, etc. and not on the rapist. #yesallwomen
# 45  #yesallwomen because when we're out dancing it's not an invitation for men to grind against us. i shouldn't have to re
# 46  #yesallwomen look at their daughters and nieces and hope they remembered to tell them every trick for staying safe.
# 47  because women who are assaulted are told it's not as big a deal if they weren't virgins. #yesallwomen
# 48  yup. or because they were afraid of what the guy would in response since he very likely wouldn't be c
# 49  because i've been only one to call out a male colleague on a sexist comment, and nobody stood up for me when he got aggressive #yesallwomen

# %% [markdown]
# *   ### <b>Immigration and Travel Ban Tweet Ids:</b>
#
# This dataset contains the tweet ids of 16,875,766 tweets related to the immigration and travel ban executive order announced by the Trump Administration in January 2017. They were collected between January 30, 2017 and April 20, 2017.
#
# The terms using for the filter were: #MuslimBan, #NoBanNoWall, #NoMuslimBan, #JFKTerminal4, #RefugeesWelcome, muslim ban, immigrant ban, immigration ban, travel ban, immigration order, #ImmigrationBan, #TravelBan.

# %%
imm = pd.read_csv('gs://csc3002/pretrain_data/tweetIDs/immigration_exec_order.txt', sep=',',  index_col = False, header=None, names =['id'])
print("There are", len(imm.index), "tweets which are in this dataset. \n\nThe subject of this dataset is the excutive order restricting immigration which trump signed,", \
     "many believe the intentional target were muslims. \nHence the predominant hashtag in this dataset is #MuslimBan or #NoMuslimBan\n\n")
tweet_ids = list(imm['id'])

#Path to directory holding all saves
path = 'gs://csc3002/pretrain_data/tweetText/immigrationTweets' 
results = lookup_tweets_ckpt(tweet_ids, api, path)
# Out:
# There are 16875766 tweets which are in this dataset.
# The subject of this dataset is the excutive order restricting immigration which trump signed, many believe the intentional target were muslims.
# Hence the predominant hashtag in this dataset is #MuslimBan or #NoMuslimBan
# Saving tweet text in directory at path gs://csc3002/pretrain_data/tweetText/immigrationTweets
#
# There are 16875766 tweet IDs to fetch
# Checkpoint saved every 500000 IDs
# Fetching tweets...
# Rate limit reached. Sleeping for: 294
# Rate limit reached. Sleeping for: 331
# Rate limit reached. Sleeping for: 302
# Rate limit reached. Sleeping for: 273
# Rate limit reached. Sleeping for: 283
# Checkpoint at tweet ID No. 500000
# Saving at path gs://csc3002/pretrain_data/tweetText/immigrationTweets/1.csv
# Rate limit reached. Sleeping for: 267
# Rate limit reached. Sleeping for: 337
# Rate limit reached. Sleeping for: 278
# Rate limit reached. Sleeping for: 303

# %%
im = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets/0.csv', sep=',',  index_col = False, header=0)
im1 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets/1.csv', sep=',',  index_col = False, header=0)
im2 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets/2.csv', sep=',',  index_col = False, header=0)
im3 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets/3.csv', sep=',',  index_col = False, header=0)
im4 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets/4.csv', sep=',',  index_col = False, header=0)
im5 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets/5.csv', sep=',',  index_col = False, header=0)
im6 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets/6.csv', sep=',',  index_col = False, header=0)
im7 = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets/7.csv', sep=',',  index_col = False, header=0)

imTweets = pd.concat([im, im1, im2, im3, im4, im5, im6, im7], axis =0)
imTweets.drop_duplicates(subset='text',inplace =True ) #Important to drop duplicates
imTweets.dropna(inplace = True)
print("\nThere are ", len(imTweets.index), "unique tweets in this csv file after dropping duplicates again")
imTweets.head(50)
# Out:
# There are  852459 unique tweets in this csv file after dropping duplicates again
#                     id  \
# 0   836058186796847108
# 1   836058145990434816
# 2   836058233672327168
# 3   836058203213422594
# 4   836058161786183680
# 5   836058249753350145
# 6   836058248646180865
# 7   836058240420999170
# 8   836058153225699329
# 9   836058141854994433
# 10  836058183844134914
# 11  836058226575589376
# 12  836058176315248640
# 13  836058250885873664
# 14  836058151690645505
# 15  836058177594671105
# 16  836058171017838593
# 17  836058153968156674
# 18  836058207604781058
# 19  836058172636942336
# 20  836058188122292225
# 21  836058239670312960
# 22  836058239456460801
# 23  836058222523895808
# 24  836058158879633408
# 25  836058208326164480
# 26  836058231386456064
# 27  836058213598576640
# 28  836058131218186240
# 29  836058210247323648
# 30  836058147848511488
# 31  836058157604536324
# 32  836058249162022912
# 33  836058246452400130
# 34  836058234523791360
# 35  836058203586711553
# 36  836058225241915392
# 37  836058221525749763
# 38  836058147206873091
# 39  836058128819097600
# 40  836058219558617088
# 41  836058187317067777
# 42  836058132652703744
# 43  836058333287088128
# 44  836058267793018880
# 45  836058277347631104
# 46  836058292547911680
# 47  836058330632114176
# 48  836058301984956416
# 49  836058292933689344
#
#                                                                                                                                                                 text
# 0   RT @thehill: Iranian director\u2019s Oscar acceptance message hits Trump travel ban https://t.co/hv88n3dhKq https://t.co/m8k65UKcZ6
# 1   RT @brianstelter: Best foreign language film: "The Salesman," directed by Asghar Farhadi, who boycotted the #Oscars due to Trump's travel b\u2026
# 2   RT @ACLU: Asghar Farhadi did not attend the #Oscars out of respect for the Iranians and people in six other countries affected by the #Musl\u2026
# 3   RT @BostonGlobe: Watch: Iranian director wins #Oscars, but skips awards show over Trump\u2019s \u2018inhumane\u2019 travel ban https://t.co/dPi2V1zcUg htt\u2026
# 4   RT @ACLU: More from Asghar Farhadi on #Muslimban at @UTAFoundation  #UnitedVoices rally https://t.co/30EkrRTJYJ
# 5   RT @CNN: The Salesman wins best Foreign Language Film, directed by Asghar Farhadi who boycotted #Oscars over Trump travel ban https://t.co/\u2026
# 6   RT @Nick_Offerman: You can just stop at "Trump rejects intelligence" https://t.co/lRlN9ws657
# 7   RT @Rosie: jail should be FANTASTIC !!! #russiagate #resist #FUN https://t.co/uPqzw7nzpk
# 8   RT @CNNent: Oscar winner #TheSalesman was directed by Asghar Farhadi, who boycotted the #Oscars over Trump's travel ban. https://t.co/qrL95\u2026
# 9   #AsgharFarhadi \U0001f339\U0001f339\U0001f339 https://t.co/WdPheCOHXY
# 10  RT @amyharvard_: I also heard Asghar Farhadi is continuing to boycott #Oscars #MuslimBan by refusing interviews after his win.
# 11  RT @ColorOfChange: #Zootopia, a film about how "tolerance is more powerful than fear of the other." Congrats Zootopia on #Oscars win tonigh\u2026
# 12  RT @THR: #Oscars: Iran's 'The Salesman' wins, filmmaker sends statement slamming Trump's "inhumane" travel ban https://t.co/gy5GoysJ6l http\u2026
# 13  @BraddJaffy @benshapiro but.....almost nothing from his statement is true. There is nothing inhumane about Trumps travel ban. It in no
# 14  RT @SuCh: Immigrants power America. Congratulations #AsgharFarhadi on your #Oscars Win! #NoBanNoWall #TheSalesman https://t.co/gUXBxcToPv
# 15  RT @funder: #Oscars winner stayed home to protest trump's #muslimban-all nominees for best foreign film boycotted. #trumprussia #russiagate\u2026
# 16  RT @ajplus: "I\u2019m sorry I\u2019m not with you tonight."\n\n#Oscars-winner Asghar Fahardi delivers a message denouncing the immigration ban. https:/\u2026
# 17  Stars protest Donald Trump's travel ban by wearing blue ribbons https://t.co/wCtNO43P8L @MailOnline
# 18  RT @MichaelEaly: Make it plain. #nomuslimban #nonewmuslimban https://t.co/q7MAOtmHo8
# 19  Oscars 2017: Iranian nominee wins after BOYCOTTING awards over Trump immigration ban | The Locus\n... https://t.co/uqtpxXkrkg
# 20  RT @amnestyusa: Waiting for more #NoBanNoWall protest speeches at the #Oscars https://t.co/RzLpEYBqMe
# 21  RT @ChrisMurphyCT: Your daily reminder that no refugee from the 7 countries named in the Muslim ban has ever done something like this. http\u2026
# 22  RT @MacleansMag: Asghar Farhadi won the Oscar for best foreign film\u2014but boycotted it over Trump's travel ban. Read his statement: https://t\u2026
# 23  RT @JohnTrumpFanKJV: Retweet if you Agree :\nNot one  dime of benefits should be given to non citizens! https://t.co/VCHO7muxTd
# 24  RT @Variety: Iranian director blasts "inhumane" travel ban in statement after winning Oscar https://t.co/JYbPyPbmyv #Oscars https://t.co/Vb\u2026
# 25  RT @brianstelter: Asghar Farhadi, in statement, calls the attempted travel ban "inhumane;" calls for more "empathy," says we need it "now m\u2026
# 26  RT @ChrisLoesch: I missed the point of his statement? He incorrectly called it an immigration ban and said it was inhumane. Crickets when O\u2026
# 27  RT @kylegriffin1: Iran's Foreign Minister \U0001f447https://t.co/Q7kIKO5iF2
# 28  RT @josferlo: Mmmmuakkkksss https://t.co/xq3biXZyAq
# 29  RT @TheJournalPost: Iranian director Asghar Farhadi blasts Trump's travel ban after winning #Oscars https://t.co/J6ffmN30nj
# 30  He is from Iran https://t.co/0peVM5PBmJ
# 31  devolve o oscar https://t.co/syWmjbt0i6
# 32  RT @viviansessoms: Iranian Director Blasts \u2018Inhumane\u2019 Travel Ban in Statement After Winning Oscar \u2013 Variety https://t.co/kvjeFmSCLP
# 33  RT @KamalaHarris: I will actively address an issue at all costs when it harms my constituents\u2014and hold @DHSgov Sec. Kelly accountable.\nhttp\u2026
# 34  #NoBanNoWall Not one dollar of my taxes goes to a wall. You do not get to do whatever you please. https://t.co/rC2Ifcpyob
# 35  RT @MazJobrani: Wow! #AsgharFarhadi wins! But isn't here b/c of #trump #travelban - proud to be Iranian tonight! #Oscars
# 36  RT @amnestyusa: "As a human being, I'm against any form of any wall that wants to separate us." @GaelGarciaB. #Oscars #NoBanNoWall https://\u2026
# 37  Canadian school boards question trips to U.S. as travel ban debate continues https://t.co/9zNwTO0YCV
# 38  RT @NegarMortazavi: Iran director Asghar Farhadi wins his second #Oscars for best foreign film The Salesman but is not there to receive it\u2026
# 39  Iranian lectures us about how the travel ban is wrong, Iran bans anyone from Israel or who has evidence of visiting\u2026 https://t.co/oNL9BRea0F
# 40  RT @NYCLU: "My absence is out of respect for those who've been disrespected by this country." -Director Farhadi #muslimban #Oscars2017 #sol\u2026
# 41  RT @BraddJaffy: Statement from Iranian director Asghar Farhadi, Oscar winner protesting Trump's \u201cinhumane\u201d immigration travel ban\nhttps://t\u2026
# 42  Asghar Farhadi criticizes U.S. travel ban after his film 'The Salesman' wins at the Oscars... #news #Chicago https://t.co/4nERgMBmgn
# 43  RT @Dgarza888: "Those who fail to learn from history..." \n#MSM #FakeNews #MAGA #TheResistance #TrumpRussia #NoBanNoWall #MuslimBan https://\u2026
# 44  RT @StopTrump2020: Immigrants come to the USA to make a better life and support their families.  #NoBanNoWall https://t.co/ZN9LpyhqQ5
# 45  Trump\u2019s Immigrant Ban Los Angeles\xa0Protests https://t.co/MpKCW7JDZn https://t.co/5BtCkhKHq6
# 46  RT @yashmori: Strong statement by not showing up at the #Oscars to protest @realDonaldTrump's muslim ban #NoBanNoWallNoRaids https://t.co/6\u2026
# 47  #RefugeesWelcome WAKE UP HOLLYWOOD. WAKE UP USA. These are dangerous people. Wake up! #oscars #islam #hollywood\u2026 https://t.co/1HnakOgYTR
# 48  RT @CeliaFreijeiro: Bravo @GaelGarciaB \U0001f64c\u2764 #Yes #NoWall #NoBanNoWall #weareone @TheAcademy #Oscars2017
# 49  Academy Awards Rejects President Trump\u2019s Muslim Ban In The Perfect Way (VIDEO) https://t.co/ji6NV3RD28 https://t.co/QAX2qIAGNc

# %%
imTweets.to_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets.csv', sep = ',', \
                encoding='utf-8', index = False, header = 0)

# %% [markdown]
# # Removing common terms for word-masking
# It has occured to me that in the way these tweet datasets were sourced - (by filtering through a particular term/hashtag via twitter API), there will be recurring terms or hashtags in each sequence - which may be counter-productive to the word masking excercise later in further BERT pre-training.
#
# <i>(Also though, removing these terms may render some sequences non-sensical - however I'm not sure how concerining this might be from an NLP standpoint) </i>
#
# Therefore I'll develop a function to remove these common terms from my tweet data. These terms can be often followed by punctuation. So I'll fill an initial list with the terms I'd like to remove, then from that I'll create an augmented list which contains all the terms, plus versions of them with punctuation at the end.
#
# <i> (I'll do further pre-training on data that has had common terms removed, as well as data that hasn't - and instead hashtags are segmented to mitigate the commonality of terms) </i>
#
# I'll convert this list into a set at the end of the function, as a set is much quicker to access than a list - which will be useful later on

# %%
#This dataset was the combo of AOC replies, #charlottesville, #blmkidnapping, #bill10 and #uniteTheRight tweets'
dat = pd.read_csv('gs://csc3002/pretrain_data/tweetText/full.csv',\
                  sep=',',  index_col = False, header=0)

list1 = ['#unitetheright', '#charlottesville', '#utr', '#blmkidnapping',\
            '#bill10', 'charlottesville']

def addPunc(wordlist):
    
    
    newlist = wordlist + [word + "." for word in wordlist] + [word + "," for word in wordlist] \
     + [word + "?" for word in wordlist] + [word + "!" for word in wordlist] + \
    [word + "-" for word in wordlist] + [word + ":" for word in wordlist] + \
    [word + ";" for word in wordlist]
    
    wordset = set(newlist) # Convert to set for faster lookup later
    return wordset

print(addPunc(list1))
# Out:
# {'charlottesville,', '#charlottesville;', '#utr:', '#charlottesville', '#charlottesville?', '#unitetheright', '#unitetheright;', '#utr!', '#blmkidnapping,', 'charlottesville!', '#charlottesville!', '#blmkidnapping?', '#bill10:', '#utr;', 'charlottesville', '#unitetheright.', 'charlottesville:', '#unitetheright:', '#unitetheright!', '#blmkidnapping.', '#utr,', '#utr?', '#blmkidnapping-', '#bill10;', 'charlottesville;', '#bill10', '#charlottesville,', '#bill10,', 'charlottesville?', '#bill10-', '#bill10?', 'charlottesville-', '#charlottesville:', '#charlottesville.', '#utr', '#utr-', '#bill10!', '#utr.', '#blmkidnapping:', '#charlottesville-', '#bill10.', '#unitetheright,', 'charlottesville.', '#blmkidnapping!', '#blmkidnapping', '#unitetheright-', '#unitetheright?', '#blmkidnapping;'}

# %%
def removeWords(text_string, wordlist):
    
    #Make sure row entry is a string
    text_string = str(text_string)
    
    # Add Punctuation to each word so function can account for occurences where string follows a punctuation mkr
    wordSet = addPunc(wordlist) 
    
    #Add spaces between hashtags. This ensures strings with consecutive hashtags are processed properly
    text_string = text_string.replace('#', ' #') 
    
    querywords = text_string.split()
    resultwords  = [word for word in querywords if word.lower() not in wordSet]
    resultwords = ' '.join(resultwords)
    return resultwords

stopwords = ['#unitetheright', '#charlottesville', '#utr', '#blmkidnapping',\
            '#bill10', 'charlottesville']

tweet = dat.iloc[10]['text']
print("Removing #unitetheright:\n")
print("Original:\n", tweet)
print("\n\nNew:\n ", removeWords(tweet, stopwords))

tweet = dat.iloc[20]['text']
print("\n\nRemoving \"charlottesville\":\n")
print("Original:\n", tweet)
print("\n\nNew:\n ", removeWords(tweet, stopwords))
# Out:
# Removing #unitetheright:
#
# Original:
#  RT @RealAlexRubi: Tons of gas deployed. Police declare an unlawful assembly outside #antifa counter-protest of #UniteTheRight #Charlottesvi\u2026
#
#
# New:
#   RT @RealAlexRubi: Tons of gas deployed. Police declare an unlawful assembly outside #antifa counter-protest of #Charlottesvi\u2026
#
#
# Removing "charlottesville":
#
# Original:
#  Trump Disbands Advisory Panels As CEOs Quit Over Charlottesville Remarks https://t.co/YuzB7mBDfq
#
#
# New:
#   Trump Disbands Advisory Panels As CEOs Quit Over Remarks https://t.co/YuzB7mBDfq

# %% [markdown]
# <b>Let's see the effect this function has</b>

# %%
dat['text'] = dat['text'].apply(removeWords, wordlist = stopwords)
dat.head(40)
# Out:
#                      id  \
# 0   1112695958540902402
# 1   1112477224412672001
# 2   816807362363265032
# 3   896356223649333248
# 4   896553831118454784
# 5   896574089741058048
# 6   898220671054086145
# 7   896365557959856128
# 8   1105931607783890944
# 9   897992781490270209
# 10  896464308758081537
# 11  1108219077489815554
# 12  897631387276247042
# 13  897666333055365124
# 14  896212564580982784
# 15  897839816536199169
# 16  897904397941735424
# 17  898001945004265473
# 18  898579676808921088
# 19  896815461098299395
# 20  898032076540309504
# 21  539892691681558528
# 22  816844563767848960
# 23  896411770763563012
# 24  897643847546785793
# 25  816842580373581825
# 26  897629776999043072
# 27  896624445628047361
# 28  896369328337154048
# 29  897696062487629824
# 30  896451977915154432
# 31  1112153570994876417
# 32  898151245067808769
# 33  897642757195526144
# 34  540587907099004928
# 35  897158220611035138
# 36  816826279408398340
# 37  897911164759412737
# 38  816836338771054592
# 39  897952576414466049
#
#                                                                                                                                                                                 text
# 0   @AOC They pay 7 billion a year in taxes and cost us 13 billion. Do the math
# 1   @AOC How do you pay taxes on free?
# 2   nan
# 3   RT @AndreaChalupa: Bannon and Gorka are actual Nazis in the White House paid by US tax payers as they spread lies and hate.
# 4   RT @RealAlexRubi: "Tight formation!": rally lights torches, preps security for march https://t.co/s0btqHigrj
# 5   RT @irmahinojosa_: Discussing deceitful politicians with @Johnny__MAGA and the rally in #ThisIsNotUs https\u2026
# 6   VICE @vicenews has produced an impeccable gem of journalism on WATCH #Nazis #ImpeachTrump #ViceNews https://t.co/NGN2OMff8v
# 7   At this point, singing clergy in street most vocal here in But rally not due to start for another 2 hrs.
# 8   @JamieRio @pramsey342 @ClintSmithIII @AOC You mean a rate closer to what they paid for the 50 years that everyone r\u2026 https://t.co/qir3Ur3Xue
# 9   @FoxNews America I like to believe YOU are smart, but YOU"RE NOT; if you heard Trump say only one thing on whose at fault
# 10  RT @RealAlexRubi: Tons of gas deployed. Police declare an unlawful assembly outside #antifa counter-protest of #Charlottesvi\u2026
# 11  @AOC @chrislhayes Proud of you my love \u2764\ufe0f
# 12  My prayers go out to Heather Heyer and her family, as she did not deserve to be ran over by the Nazi in his vehicle.
# 13  \U0001f495\U0001f1e8\U0001f1e6 https://t.co/fvIAzaxMoK
# 14  RT @MikeTokes: Live now: @aletweetsnews on #Periscope: BREAKING: Scuffles at alt-right torch rally on UVA campus https://t.c\u2026
# 15  @TomiLahren So, you are saying they are terrorists? And white supremacists are like terrorists?
# 16  Poor little snowflake. Here he is discussing Fu*kFace45 before Sat.'s rally:\nhttps://t.co/W8Ye6Jn8CC https://t.co/d2BL1x20U7
# 17  America, you're doing amazing sweetie \u2764\ufe0f\U0001f499 https://t.co/Q8hwhgpmoa
# 18  la m\xe8re de la victime refuse de parler \xe0\xa0Trump https://t.co/kyA2PWthav
# 19  RT @NBC29: MORE: While attempting to hold a press conference, organizer, Jason Kessler gets swarmed and punched in the face.\u2026
# 20  Trump Disbands Advisory Panels As CEOs Quit Over Remarks https://t.co/YuzB7mBDfq
# 21  RT @vsp: "What year is it?" #bill202 #ableg #abpoli http://t.co/C8UzQmBhgF
# 22  RT @PrisonPlanet: Tucker is the only national mainstream reporter to cover this. https://t.co/gNaBrifiLm https://t.co/223ire\u2026
# 23  RT @sjredmond: Dear marchers in #Charlottesville:\n\nThe American tribe has spoken. Take your hate filled Tiki Torches and lea\u2026
# 24  Republicans denounce bigotry after Trump's latest remarks - Reactions to the president\u2019s controversial press conference ...
# 25  RT @KazeSkyz: Four blacks kidnapped and TORTURED a DISABLED white man - yet @AC360 is reporting on THE BACHELOR??\n\n https://t\u2026
# 26  Vox: North Korea Backed Down Because of... https://t.co/gRWzvxUzuY #MediaBias #MSM https://t.co/SHzRGzqgvU
# 27  RT @UR_Ninja: Car plows into #antifascist protest in Many people injured, some possibly dead #Defendcville #UniteTheRight\u2026
# 28  RT @RealAlexRubi: Massive brawl breaks out, tiki torches thrown as reaches Jefferson monument in Chemicals\u2026
# 29  Race and Terror \u2013 VICE News Tonight on HBO https://t.co/jwsUtbB1Se @JoeNBC #morningjoe @tomkeene @bsurveillance
# 30  RT @RyanMKellyPhoto: A vehicle plowed into a crowd of protesters after events around declared unlawful assembly https://t.co\u2026
# 31  @MarciaJ91882912 @AOC https://t.co/3y5BQuuC4I
# 32  violence revives painful past for minorities https://t.co/F6Dl1g616M
# 33  "@justdawn_ @mmpadellan @CampbellSoupCo @NewYorkFBI @FBICharlotte @CvilleCityHall @cvillenews @charlotsv_crime call whom ever send this get it sorted out. SIC #Charlottesville"
# 34  RT @aldjohnmar: If you're 15 years old &amp; LBGT are you seriously going to fight your school too? Probably not. #ableg
# 35  I never supported the rally although I share some of their grievances. We shouldn't be removing public historical statues.
# 36  Look I'm a democrat but the is real if we don't talk about it we are wrong on both ends. Democrats need to talk about trump..
# 37  attack puts a spotlight on online\xa0hate https://t.co/u4yCWEJFfu
# 38  RT @joshgremillion: How disgusting is this?! Brittany Herring and her friends should be thrown in jail for this. #Viral #Dis\u2026
# 39  "@jomeara555 @williamlegate #StopThePunk Sooner the better How many @GOP will be sent home next election? https://t.co/WxzGCFM2zZ"

# %%
dat.to_csv('gs://csc3002/pretrain_data/tweetText/removedTerms/full.csv', sep = ',', encoding='utf-8', index = False, header = 0)

# %% [markdown]
# <b>Likewise we'll remove common terms for the #thechalkening tweet database. I just see the term #thechalkening come up often</b>

# %%
#This is the #thechalkening databse
chalk = pd.read_csv('gs://csc3002/pretrain_data/tweetText/chalkTweets.csv', sep=',',  index_col = False, header=0)
chalk.head(10)
# Out:
#                    id  \
# 0  720103525401931777
# 1  720107446149193728
# 2  720102290749841408
# 3  720103135440715776
# 4  720100823729102848
# 5  720104336202821632
# 6  720101963812233216
# 7  720140123141185537
# 8  720116749765582848
# 9  720102767130472450
#
#                                                                                                                                                                      text
# 0  RT @DanScavino: #TheChalkening- thank you! #Trump2016 #StudentsForTrump https://t.co/W6aTj6TzzL
# 1  RT @2AFight: 19 yr old Kurdish girl celebrates 1 year of fighting #ISIS... needs no #SafeSpace from #TheChalkening\n\n#tcot\n#PJNET https://t.\u2026
# 2  Sullivan County NY Loves #Trump #TheChalkening #Trump2016 #MAGA \U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8 https://t.co/u4k7jUogB8
# 3  RT @RoyBatty010816: Next thing you know there will be a background check and waiting period to buy chalk.\n#TheChalkening https://t.co/L9puO\u2026
# 4  RT @anamericanfam: HUGE props to @AndersonU students who conducted #TheChalkening on campus! Together, WE will #MakeAmericaGreatAgain https\u2026
# 5  RT @LainieYennie: Sullivan County NY Loves #Trump #TheChalkening #Trump2016 #MAGA \U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8 https://t.co/u4k7jUogB8
# 6  RT @TomatoPie1: .@DanScavino #TheChalkening At shopping malls! Libraries! Especially Starbucks! Everywhere\n#Trump2016 #TrumpNewYork https:/\u2026
# 7  RT @TrumpStudents: We will not be silenced! WE WILL WIN! #TeamTrump #Trump2016 #TheChalkening #StudentsForTrump #StandWithStudents https://\u2026
# 8  a trump supporter once said, "in real life, there are no safe spaces" #thechalkening https://t.co/5sAkx3zZTd
# 9  You can wash it off, but you can't erase Trump support at NU! #TheChalkening @TrumpStudentsIL @ILStudentsforTrump https://t.co/iAGZbF14X9

# %% [markdown]
# Remove common terms...

# %%
stopwords = ['#thechalkening']
chalk['text'] = chalk['text'].apply(removeWords, wordlist = stopwords)
chalk.head(10)
# Out:
#                    id  \
# 0  720103525401931777
# 1  720107446149193728
# 2  720102290749841408
# 3  720103135440715776
# 4  720100823729102848
# 5  720104336202821632
# 6  720101963812233216
# 7  720140123141185537
# 8  720116749765582848
# 9  720102767130472450
#
#                                                                                                                                                       text
# 0  RT @DanScavino: thank you! #Trump2016 #StudentsForTrump https://t.co/W6aTj6TzzL
# 1  RT @2AFight: 19 yr old Kurdish girl celebrates 1 year of fighting #ISIS... needs no #SafeSpace from #TheChalkening\n\n #tcot\n #PJNET https://t.\u2026
# 2  Sullivan County NY Loves #Trump #Trump2016 #MAGA \U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8 https://t.co/u4k7jUogB8
# 3  RT @RoyBatty010816: Next thing you know there will be a background check and waiting period to buy chalk.\n https://t.co/L9puO\u2026
# 4  RT @anamericanfam: HUGE props to @AndersonU students who conducted on campus! Together, WE will #MakeAmericaGreatAgain https\u2026
# 5  RT @LainieYennie: Sullivan County NY Loves #Trump #Trump2016 #MAGA \U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8 https://t.co/u4k7jUogB8
# 6  RT @TomatoPie1: .@DanScavino At shopping malls! Libraries! Especially Starbucks! Everywhere\n #Trump2016 #TrumpNewYork https:/\u2026
# 7  RT @TrumpStudents: We will not be silenced! WE WILL WIN! #TeamTrump #Trump2016 #StudentsForTrump #StandWithStudents https://\u2026
# 8  a trump supporter once said, "in real life, there are no safe spaces" https://t.co/5sAkx3zZTd
# 9  You can wash it off, but you can't erase Trump support at NU! @TrumpStudentsIL @ILStudentsforTrump https://t.co/iAGZbF14X9

# %% [markdown]
# And Save

# %%
chalk.to_csv('gs://csc3002/pretrain_data/tweetText/removedTerms/chalkTweets.csv', sep = ',', \
             encoding='utf-8', index = False, header = 0)

# %% [markdown]
# <b>And for the #NotAllMen and #NotAllWomen databases</b>

# %%
final = pd.read_csv('gs://csc3002/pretrain_data/tweetText/sexismTweets.csv',sep=',',  index_col = False)
final.head(10)
# Out:
#                    id  \
# 0  470578066662895616
# 1  471061943965720577
# 2  470472133622390784
# 3  470573365195857921
# 4  471516144093122560
# 5  471321319833735168
# 6  470836290204991488
# 7  470976100760158209
# 8  472034665843687425
# 9  470814489017729024
#
#                                                                                                                                                 text
# 0  RT @Eidelonn: #notallmen are rapists but ANY MAN could be,from anywhere and at any time, so #YesAllWomen live in fear.
# 1  RT @so_unimpressed: No, #notallmen are rapists and murderers, but #yesallwomen are still in danger of being raped or murdered just because \u2026
# 2  RT @schemaly: #notallmen practice violence against women but #YesAllWomen live with the threat of male violence. Every. Single. Day. All ov\u2026
# 3  RT @karinjr: No, #NotAllMen are violent against women, but #YesAllWomen have to navigate a world where those who are look the same as those\u2026
# 4  RT @alliasan: Because #YesAllWomen have to endure near daily harassment in their adult lives, but #notallmen can handle hearing this for 4 \u2026
# 5  RT @kpmiracle: #NotAllMen are violent against women, but if we are just passive bystanders then we're still part of the problem. #YesAllWom\u2026
# 6  I hate this fad but this gif is great #NotAllMen #Castlevania #vampires  http://t.co/4qYILg2tWV
# 7  RT @GenericPsycho: Maybe #notallmen are rapists, but #YesAllWomen are terrified of passing men on the street, walking home alone, going out\u2026
# 8  Enough w/the #notallmen defense, men. Women KNOW we're not all like that. Stop stealing spotlight w/whining &amp;  support women. #YesAllWomen
# 9  RT @dxtehsecks: In all seriousness though, the contrast between #YesAllWomen and #NotAllMen has been an eye opener

# %%
stopwords = ['#notallmen', '#notallwomen', '#yesallwomen']
tweet = final.iloc[650]['text']

print("Original:\n", tweet)
print("\n\nNew:\n ", removeWords(tweet, stopwords))

final['text'] = final['text'].apply(removeWords, wordlist = stopwords)
final.head(10)
# Out:
# Original:
#  And I hate it. #YesAllWomen have dealt with shitty men doing shitty things, &amp; yes, #NotAllMen are awful. #RiseAboveHate
#
#
# New:
#   And I hate it. have dealt with shitty men doing shitty things, &amp; yes, are awful. #RiseAboveHate
#                    id  \
# 0  470578066662895616
# 1  471061943965720577
# 2  470472133622390784
# 3  470573365195857921
# 4  471516144093122560
# 5  471321319833735168
# 6  470836290204991488
# 7  470976100760158209
# 8  472034665843687425
# 9  470814489017729024
#
#                                                                                                                                      text
# 0  RT @Eidelonn: are rapists but ANY MAN could be,from anywhere and at any time, so live in fear.
# 1  RT @so_unimpressed: No, are rapists and murderers, but are still in danger of being raped or murdered just because \u2026
# 2  RT @schemaly: practice violence against women but live with the threat of male violence. Every. Single. Day. All ov\u2026
# 3  RT @karinjr: No, are violent against women, but have to navigate a world where those who are look the same as those\u2026
# 4  RT @alliasan: Because have to endure near daily harassment in their adult lives, but can handle hearing this for 4 \u2026
# 5  RT @kpmiracle: are violent against women, but if we are just passive bystanders then we're still part of the problem. #YesAllWom\u2026
# 6  I hate this fad but this gif is great #Castlevania #vampires http://t.co/4qYILg2tWV
# 7  RT @GenericPsycho: Maybe are rapists, but are terrified of passing men on the street, walking home alone, going out\u2026
# 8  Enough w/the defense, men. Women KNOW we're not all like that. Stop stealing spotlight w/whining &amp; support women.
# 9  RT @dxtehsecks: In all seriousness though, the contrast between and has been an eye opener

# %%
final.to_csv('gs://csc3002/pretrain_data/tweetText/removedTerms/sexismTweets.csv', sep = ',', \
             encoding='utf-8', index = False, header = 0)

# %% [markdown]
# <b>#YesAllWomen Dataset</b>

# %%
womTweets = pd.read_csv('gs://csc3002/pretrain_data/tweetText/YesAllWomenTweets.csv',sep=',',  index_col = False, names =['id', 'text'])
womTweets.head(10)
# Out:
#                    id  \
# 0  470315730706399232
# 1  470317902776647680
# 2  470315567233372160
# 3  470315805222404096
# 4  470317461024555009
# 5  470317579920506880
# 6  470316502445744130
# 7  470317309022978048
# 8  470315890060189696
# 9  470314968492302338
#
#                                                                                                                                                 text
# 0  Because I get in an elevator with a guy and think "what's my escape plan going to be?" #YesAllWomen
# 1  RT @Ava_Jae: Because it starts early\u2014school dress codes punish girls for wearing clothes that are "distracting" to boys. #YesAllWomen
# 2  RT @anniecardi: Because women are taught to carry our keys like a weapon in case we're attacked in a parking lot. #YesAllWomen
# 3  RT @anniecardi: Because I get in an elevator with a guy and think "what's my escape plan going to be?" #YesAllWomen
# 4  RT @anniecardi: Because "boys will be boys" is a phrase that still exists. #YesAllWomen
# 5  Because it starts early\u2014school dress codes punish girls for wearing clothes that are "distracting" to boys. #YesAllWomen
# 6  RT @anniecardi: Because we're taught "never leave your drink alone," instead of "don't drug someone."  #YesAllWomen
# 7  #YesAllWomen have the right to set boundaries. Prevalent misogyny has led to the extinction of private space for women.
# 8  RT @Ceilidhann: @anniecardi @gildedspine Hell yeah. #YesAllWomen deserve the right to say no to a man without a given reason. They owe you \u2026
# 9  @gildedspine @Ceilidhann Sounds like something that needs to get shared right now. #YesAllWomen

# %%
#A lot of the tweets follow the format "because.... -comes up too often"
tweet = womTweets.iloc[650]['text']
stopwords = ['because', '#yesallwomen']

print("Original:\n", tweet)
print("\n\nNew:\n ", removeWords(tweet, stopwords))

womTweets['text'] = womTweets['text'].apply(removeWords, wordlist = stopwords)
# Out:
# Original:
#  FYI #YesAllWomen includes WOC, trans women, women w/ disabilities, sex workers, celibate women, and non-binary people read as women.
#
#
# New:
#   FYI includes WOC, trans women, women w/ disabilities, sex workers, celibate women, and non-binary people read as women.

# %%
womTweets.to_csv('gs://csc3002/pretrain_data/tweetText/removedTerms/YesAllWomenTweets.csv', sep = ',', \
                 encoding='utf-8', index = False, header = 0)
womTweets.head(10)
# Out:
#                    id  \
# 0  470315730706399232
# 1  470317902776647680
# 2  470315567233372160
# 3  470315805222404096
# 4  470317461024555009
# 5  470317579920506880
# 6  470316502445744130
# 7  470317309022978048
# 8  470315890060189696
# 9  470314968492302338
#
#                                                                                                                                    text
# 0  I get in an elevator with a guy and think "what's my escape plan going to be?"
# 1  RT @Ava_Jae: it starts early\u2014school dress codes punish girls for wearing clothes that are "distracting" to boys.
# 2  RT @anniecardi: women are taught to carry our keys like a weapon in case we're attacked in a parking lot.
# 3  RT @anniecardi: I get in an elevator with a guy and think "what's my escape plan going to be?"
# 4  RT @anniecardi: "boys will be boys" is a phrase that still exists.
# 5  it starts early\u2014school dress codes punish girls for wearing clothes that are "distracting" to boys.
# 6  RT @anniecardi: we're taught "never leave your drink alone," instead of "don't drug someone."
# 7  have the right to set boundaries. Prevalent misogyny has led to the extinction of private space for women.
# 8  RT @Ceilidhann: @anniecardi @gildedspine Hell yeah. deserve the right to say no to a man without a given reason. They owe you \u2026
# 9  @gildedspine @Ceilidhann Sounds like something that needs to get shared right now.

# %% [markdown]
# <b>Immigration Executive Order Dataset</b>

# %%
imTweets = pd.read_csv('gs://csc3002/pretrain_data/tweetText/immigrationTweets.csv',sep=',',  index_col = False, names = ['id', 'text'])
imTweets.head(10)
# Out:
#                    id  \
# 0  836058186796847108
# 1  836058145990434816
# 2  836058233672327168
# 3  836058203213422594
# 4  836058161786183680
# 5  836058249753350145
# 6  836058248646180865
# 7  836058240420999170
# 8  836058153225699329
# 9  836058141854994433
#
#                                                                                                                                                                text
# 0  RT @thehill: Iranian director\u2019s Oscar acceptance message hits Trump travel ban https://t.co/hv88n3dhKq https://t.co/m8k65UKcZ6
# 1  RT @brianstelter: Best foreign language film: "The Salesman," directed by Asghar Farhadi, who boycotted the #Oscars due to Trump's travel b\u2026
# 2  RT @ACLU: Asghar Farhadi did not attend the #Oscars out of respect for the Iranians and people in six other countries affected by the #Musl\u2026
# 3  RT @BostonGlobe: Watch: Iranian director wins #Oscars, but skips awards show over Trump\u2019s \u2018inhumane\u2019 travel ban https://t.co/dPi2V1zcUg htt\u2026
# 4  RT @ACLU: More from Asghar Farhadi on #Muslimban at @UTAFoundation  #UnitedVoices rally https://t.co/30EkrRTJYJ
# 5  RT @CNN: The Salesman wins best Foreign Language Film, directed by Asghar Farhadi who boycotted #Oscars over Trump travel ban https://t.co/\u2026
# 6  RT @Nick_Offerman: You can just stop at "Trump rejects intelligence" https://t.co/lRlN9ws657
# 7  RT @Rosie: jail should be FANTASTIC !!! #russiagate #resist #FUN https://t.co/uPqzw7nzpk
# 8  RT @CNNent: Oscar winner #TheSalesman was directed by Asghar Farhadi, who boycotted the #Oscars over Trump's travel ban. https://t.co/qrL95\u2026
# 9  #AsgharFarhadi \U0001f339\U0001f339\U0001f339 https://t.co/WdPheCOHXY

# %%
tweet = imTweets.iloc[4]['text']
stopwords = ['#muslimban', '#nobannowall', '#nomuslimban','#JFKTerminal4',\
             '#refugeeswelcome', '#immigrationban', '#TravelBan']
             
print("Original:\n", tweet)
print("\n\nNew:\n ", removeWords(tweet, stopwords))

imTweets['text'] = imTweets['text'].apply(removeWords, wordlist = stopwords)
# Out:
# Original:
#  RT @ACLU: More from Asghar Farhadi on #Muslimban at @UTAFoundation  #UnitedVoices rally https://t.co/30EkrRTJYJ
#
#
# New:
#   RT @ACLU: More from Asghar Farhadi on at @UTAFoundation #UnitedVoices rally https://t.co/30EkrRTJYJ

# %%
imTweets.to_csv('gs://csc3002/pretrain_data/tweetText/removedTerms/immigrationTweets.csv', sep = ',', \
                 encoding='utf-8', index = False, header = 0)
imTweets.head(10)
# Out:
#                    id  \
# 0  836058186796847108
# 1  836058145990434816
# 2  836058233672327168
# 3  836058203213422594
# 4  836058161786183680
# 5  836058249753350145
# 6  836058248646180865
# 7  836058240420999170
# 8  836058153225699329
# 9  836058141854994433
#
#                                                                                                                                                                text
# 0  RT @thehill: Iranian director\u2019s Oscar acceptance message hits Trump travel ban https://t.co/hv88n3dhKq https://t.co/m8k65UKcZ6
# 1  RT @brianstelter: Best foreign language film: "The Salesman," directed by Asghar Farhadi, who boycotted the #Oscars due to Trump's travel b\u2026
# 2  RT @ACLU: Asghar Farhadi did not attend the #Oscars out of respect for the Iranians and people in six other countries affected by the #Musl\u2026
# 3  RT @BostonGlobe: Watch: Iranian director wins #Oscars, but skips awards show over Trump\u2019s \u2018inhumane\u2019 travel ban https://t.co/dPi2V1zcUg htt\u2026
# 4  RT @ACLU: More from Asghar Farhadi on at @UTAFoundation #UnitedVoices rally https://t.co/30EkrRTJYJ
# 5  RT @CNN: The Salesman wins best Foreign Language Film, directed by Asghar Farhadi who boycotted #Oscars over Trump travel ban https://t.co/\u2026
# 6  RT @Nick_Offerman: You can just stop at "Trump rejects intelligence" https://t.co/lRlN9ws657
# 7  RT @Rosie: jail should be FANTASTIC !!! #russiagate #resist #FUN https://t.co/uPqzw7nzpk
# 8  RT @CNNent: Oscar winner #TheSalesman was directed by Asghar Farhadi, who boycotted the #Oscars over Trump's travel ban. https://t.co/qrL95\u2026
# 9  #AsgharFarhadi \U0001f339\U0001f339\U0001f339 https://t.co/WdPheCOHXY
