# %% [markdown]
# # Data Augmentation Through Backtranslation
# The backtranslation method we use is a neural network model whose checkpoint we must load from google. We use a GPU to run this. Below we test if a GPU is available

# %%
#We need the gpu compatible version in the environment
#!pip install tensorflow-gpu==1.14
import tensorflow as tf
import pandas as pd
import re
import html
import os
#!tensorflow_version 1.x

"""device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
"""

#Get GCS Bucket Access
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]= "C:/Users/fionn/Downloads/storageCreds.json"
from google.cloud import storage
storage_client = storage.Client()
buckets = list(storage_client.list_buckets())
print("If access has been granted, below will print GCS project name:")
print(buckets) # Testing if access to GCS has been granted

pd.set_option('display.max_colwidth', -1)

print("Tensorflow version must be 1.x")
print("Tensorflow version", tf.__version__)
# Out:
# If access has been granted, below will print GCS project name:
# [<Bucket: csc3002>]
# Tensorflow version must be 1.x
# Tensorflow version 1.5.0

# %% [markdown]
# ## Data
# I've stored the dataset in my google drive for ease of access, authentication will have to be provided

# %%
DATASET = 'HatEval'

if DATASET == 'AnalyticsVidhya':   
    data = pd.read_csv('./Raw_Data/AnalyticsVidhya/train_E6oV3lV.csv' ,\
                       sep=',',  index_col = False, encoding = 'utf-8')
else:

#For HatEval
    train = pd.read_csv('./Raw_Data/hateval2019/hateval2019_en_train.csv', \
                    sep=',',  index_col = False, encoding = 'utf-8')

    dev = pd.read_csv('./Raw_Data/hateval2019/hateval2019_en_dev.csv',\
                  sep=',',  index_col = False, encoding = 'utf-8')

    data = pd.concat([train,dev], axis=0)
    
    
data.drop_duplicates(inplace=True)
data.rename(columns={'text': 'tweet', 'HS': 'label'}, inplace=True)


data.head()
# Out:
#     id  \
# 0  201
# 1  202
# 2  203
# 3  204
# 4  205
#
#                                                                                                                                                                                                                                                                                                           tweet  \
# 0  Hurray, saving us $$$ in so many ways @potus @realDonaldTrump #LockThemUp #BuildTheWall #EndDACA #BoycottNFL #BoycottNike
# 1  Why would young fighting age men be the vast majority of the ones escaping a war &amp; not those who cannot fight like women, children, and the elderly?It's because the majority of the refugees are not actually refugees they are economic migrants trying to get into Europe.... https://t.co/Ks0SHbtYqn
# 2  @KamalaHarris Illegals Dump their Kids at the border like Road Kill and Refuse to Unite! They Hope they get Amnesty, Free Education and Welfare Illegal #FamilesBelongTogether in their Country not on the Taxpayer Dime Its a SCAM #NoDACA #NoAmnesty #SendThe
# 3  NY Times: 'Nearly All White' States Pose 'an Array of Problems' for Immigrants https://t.co/ACZKLhdMV9 https://t.co/CJAlSXCzR6
# 4  Orban in Brussels: European leaders are ignoring the will of the people, they do not want migrants https://t.co/NeYFyqvYlX
#
#    label  TR  AG
# 0  1      0   0
# 1  1      0   0
# 2  1      0   0
# 3  0      0   0
# 4  0      0   0

# %%
print(data.label.value_counts(), "\n")
data.info()
# Out:
# 0    5790
# 1    4210
# Name: label, dtype: int64
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 999
# Data columns (total 5 columns):
# id       10000 non-null int64
# tweet    10000 non-null object
# label    10000 non-null int64
# TR       10000 non-null int64
# AG       10000 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 468.8+ KB

# %% [markdown]
# # Text Pre-Processing
# We preprocess the text with the same techniques we'd use in traininig and pre-training. With the addition of removing punctuation so we can ensure our sentences are parsed correctly by the backtranslation model - (as it uses quotation marks to separate sequences and we don't want already existing quotation marks in sequences ruining that distinction).

# %%
# !cd 'Unsupervised_Data_Augmentation'
# !dir
# Out:
# The system cannot find the path specified.
#  Volume in drive C is Windows
#  Volume Serial Number is 8610-A966
#
#  Directory of C:\Users\fionn\Documents\CSC3002_Project\CSC3002_Detecting_Hate_Speech_On_Social_Media\csc3002_detecting_hate_speech
#
# 04/04/2020  12:39    <DIR>          .
# 04/04/2020  12:39    <DIR>          ..
# 04/04/2020  12:05    <DIR>          .ipynb_checkpoints
# 31/03/2020  19:14    <DIR>          bert
# 31/03/2020  18:40    <DIR>          Fine_Tuning
# 31/03/2020  18:38    <DIR>          Pre_Training
# 04/04/2020  12:22    <DIR>          Raw_Data
# 12/02/2020  14:09             2,268 README.md
# 31/03/2020  18:38    <DIR>          Report
# 31/03/2020  18:45    <DIR>          Text_Preprocessing
# 04/04/2020  12:06    <DIR>          Unsupervised_Data_Augmentation
# 04/04/2020  12:39         2,072,756 Unsupervised_Data_Augmentation.ipynb
# 04/04/2020  12:11         5,023,017 Visualisations.ipynb
#                3 File(s)      7,098,041 bytes
#               10 Dir(s)  333,341,782,016 bytes free

# %%
# !cd ../Text_Preprocessing/
#!ls
import preprocessing as pre
#Return to original workspace
# !cd ..
# !cd Unsupervised_Data_Augmentation


#Function caller can optionally load two dataframes and combine them
def loadData(data1, data2 = None):
    if data2 is not None:
        
        frames = [data1,data2]
        data = pd.concat(frames)
    else:
        data = data1

      #Replace emoji must be done before basic preprocess otherwise unicode will be wiped out
      #And this function will be ineffective
    if EMOJI_REPLACEMENT == 'Replace_Emoji_v1':
        data['tweet'] = data['tweet'].apply(pre.emojiReplace)

    if EMOJI_REPLACEMENT == 'Replace_Emoji_v2':
        data['tweet'] = data['tweet'].apply(pre.emojiReplace_v2)

    #Must be performed after emoji translation
    data['tweet'] = data['tweet'].apply(pre.preprocess)

    if HASHTAG_SEGMENTATION == True:
        data['tweet'] = data['tweet'].apply(pre.hashtagSegment)

    if REMOVE_PUNCTUATION == True:
        data['tweet'] = data['tweet'].apply(lambda x: pre.remove_punct(x))

    if REMOVE_STOPWORDS == True:
        data['tweet'] = data['tweet'].apply(lambda x: pre.remove_stopwords(x))

    if LEMMATIZE == True:
        data['tweet'] = data['tweet'].apply(lambda x: pre.lemmatizing(x))


    data.dropna(inplace = True)
    data.reset_index(drop = True, inplace = True) 
    if DATASET == "AnalyticsVidhya"  and len(data.index) < 20000:
        return data
    else:
        #We don't shuffle data when it is the analytics vidhya test set
        data = data.sample(frac = 1, random_state=SEED) # Shuffle data 
        return data

#Testing function
data = loadData(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-2e17d326e9fe> in <module>
#       1 get_ipython().system('cd ./Text_Preprocessing/')
#       2 #!ls
# ----> 3 import preprocessing as pre
#       4 #Return to original workspace
#       5 get_ipython().system('cd ..')
#
# ModuleNotFoundError: No module named 'preprocessing'

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 8610-A966
#
#  Directory of C:\Users\fionn\Documents\CSC3002_Project\CSC3002_Detecting_Hate_Speech_On_Social_Media\csc3002_detecting_hate_speech
#
# 04/04/2020  12:37    <DIR>          .
# 04/04/2020  12:37    <DIR>          ..
# 04/04/2020  12:05    <DIR>          .ipynb_checkpoints
# 31/03/2020  19:14    <DIR>          bert
# 31/03/2020  18:40    <DIR>          Fine_Tuning
# 31/03/2020  18:38    <DIR>          Pre_Training
# 04/04/2020  12:22    <DIR>          Raw_Data
# 12/02/2020  14:09             2,268 README.md
# 31/03/2020  18:38    <DIR>          Report
# 31/03/2020  18:45    <DIR>          Text_Preprocessing
# 04/04/2020  12:06    <DIR>          Unsupervised_Data_Augmentation
# 04/04/2020  12:37         2,070,380 Unsupervised_Data_Augmentation.ipynb
# 04/04/2020  12:11         5,023,017 Visualisations.ipynb
#                3 File(s)      7,095,665 bytes
#               10 Dir(s)  333,342,019,584 bytes free

# %% [markdown]
# # Advanced pre-processing - Unsupervised Data Augmentation
# The code below is where I implement Unsupervised Data Augmentation on the tweets annotated as hate speech in my dataset - as there is an inbalance of them compared to the benign tweets, (hate speech tweets make up 7% of analyticsvidhya dataset).
#
# This git project (https://github.com/google-research/uda) provides back-translation data augmentation, which is a paraphrasing tool that promises boosts in performance. I have previously cloned the git project into my google bucket and will retrieve functionality from there
#
# We can git clone the project and run the commands necessary to retrieve the backtranslation model and run it on our hate speech tweets below

# %%
#Already done the below
"""original = '/content'
# %cd '/content/drive/My Drive'
# !git clone https://github.com/google-research/uda.git"""
# Out:
# "original = '/content'\n%cd '/content/drive/My Drive'\n!git clone https://github.com/google-research/uda.git"

# %% [markdown]
# **Save our hate speech tweets into the back_translate subdirectory of the git project**
#
# Also we must edit manually the run.sh and download.sh powershell scripts to run on our tweettxt text file instead of the example_file in the original git project.
#
# Download the existing scripts and edit them locally, then return them to the google drive folder becausegoogle drive won't let us edit them in the drive at the moment (says we need authentication or something)

# %%
hatetweets = data.loc[data['label'] == 1]
hatetweets.tweet = hatetweets.tweet.apply(preprocess)
hatetweets = hatetweets.tweet
hatetweets.to_csv('/content/drive/My Drive/uda/back_translate/hateEvaltweettxt.txt', header=None, index=None, sep=' ', mode='a')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   after removing the cwd from sys.path.

# %%
pd.set_option('display.max_colwidth', -1)
print(len(hatetweets))
hatetweets.head(50)
# Out:
# 4210
# 0      hurray, saving us $$$ in so many ways #lockthemup #buildthewall #enddaca #boycottnfl #boycottnike
# 1      why would young fighting age men be the vast majority of the ones escaping a war and not those who cannot fight like women, children, and the elderly?it's because the majority of the refugees are not actually refugees they are economic migrants trying to get into europe....
# 2      illegals dump their kids at the border like road kill and refuse to unite! they hope they get amnesty, free education and welfare illegal #familesbelongtogether in their country not on the taxpayer dime its a scam #nodaca #noamnesty #sendthe
# 5      legal is. not illegal. #buildthatwall
# 11     illegals are dumping their kids heres o they can get welfare, aid and u.s school ripping off u.s taxpayers #sendthemback ! stop alowing illegals to abuse the taxpayer #immigration via
# 15     lithuania, romania aided cia torture, top european union court rules eu court is a joke ! why are they silent as europe is being destroyed with forced islamist immigration...
# 101    after is is soon finished (us+turkey secretserv. action), is fighter have 11000 open syrian passports for use. stop immigration to europe.
# 102    boy, they sure hated being separated from their kids, didn't they?#liberalismisamentaldisorderthe kids shouldn't get to stay!!! #deportthemall #endfamilyseparation!#stopcatchandrelease
# 106    real talk do you have eyes or were they gouged out by a rapefugee?
# 107    #wakeup #spain !! stop #illegalimmigration , and #sendthemback .
# 108    as long as it takes to #buildthatwall
# 112    danger treasonous individuals paid for by soros and globalist #lockherup #buildthewall #boycottnike #boycottnfl #enddaca now !!!!!
# 113    good news !illegal aliens claiming fake asylum are being deported in record numbers not #heretostay #immigration #rednationrising #trump #maga #sendthemhome via
# 116    good morning patriots xx let everything we do be done with them in mind.#walkawayfromdemocrats #buildthatwall #maga #chooselife #votedemsout #redwave2018 #midterms #votered #tinylivesatstake
# 118    the german government pays for 3 week vacation for refugees to go home #muslimimmigration no the german government isn't paying, the german taxpayers are paying! the german government is robbing native germans to finance the islamization of germany.
# 121    great article on the #refugee crisis in europe. "the driving question for europeans is: “how do we make it stop?” but it refers not to the humanitarian drama of the forcibly displaced, just to their ability to reach europe."
# 125    how about a gofundme for a few hundred million dollars, to build a wall along the border side of this farm? #buildthewall #buildthatwall #buildthedamnwall
# 129    here illegally you are breaking the law! the laws states you get deported not a choice ! you dont get to come to the u.s illegally ,feel entitled demand to stay , ake jobs from citizens and steal u.s resources #trump #maga #sendthemhome
# 133    i bit my toungue when l heard syrian refugees complain about rothsey then again , maybe someone can swop them with a high rise
# 135    75% of illegal aliens commit felons such as id, ssn and welfare theft illegal #immigration is not a victimless crime !
# Name: tweet, dtype: object

# %% [markdown]
# Install Dependencies and naviagate into subdirectory which contains powershell commands that perform unsupervised data augmentation on our tweets

# %%
# %cd '/content/drive/My Drive/uda/back_translate'

# %pip install --user absl-py
# %pip install --user nltk
# !python -c "import nltk; nltk.download('punkt')"
# %pip install tensor2tensor==1.14.0
# Out:
# /content/drive/My Drive/uda/back_translate
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (0.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py) (1.12.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.12.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Collecting tensor2tensor==1.14.0
#   Downloading https://files.pythonhosted.org/packages/64/75/e8fab6e46fcfaf278998b9d0a182361eaa1a9b5a9a7ecb58a0796d9e5229/tensor2tensor-1.14.0-py2.py3-none-any.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 4.7MB/s
# Requirement already satisfied: grpcio in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.3.3)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.3.2)
# Requirement already satisfied: tensorflow-gan in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (2.0.0)
# Requirement already satisfied: tensorflow-probability in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (0.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (4.28.1)
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (0.15.4)
# Requirement already satisfied: flask in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.1.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (0.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (4.3.0)
# Requirement already satisfied: mesh-tensorflow in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (0.1.7)
# Requirement already satisfied: bz2file in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (0.98)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (4.1.2.30)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.12.0)
# Requirement already satisfied: pypng in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (0.0.20)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (0.2.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (2.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.17.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (2.21.0)
# Requirement already satisfied: gunicorn in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (20.0.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.1.1)
# Requirement already satisfied: gevent in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.4.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (4.1.3)
# Requirement already satisfied: dopamine-rl in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.0.5)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (1.7.11)
# Requirement already satisfied: kfac in /usr/local/lib/python3.6/dist-packages (from tensor2tensor==1.14.0) (0.2.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets->tensor2tensor==1.14.0) (1.11.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets->tensor2tensor==1.14.0) (2.2.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets->tensor2tensor==1.14.0) (19.3.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets->tensor2tensor==1.14.0) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets->tensor2tensor==1.14.0) (3.10.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets->tensor2tensor==1.14.0) (0.3.1.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets->tensor2tensor==1.14.0) (0.8.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets->tensor2tensor==1.14.0) (0.15.1)
# Requirement already satisfied: tensorflow-hub>=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gan->tensor2tensor==1.14.0) (0.7.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability->tensor2tensor==1.14.0) (4.4.1)
# Requirement already satisfied: cloudpickle>=0.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability->tensor2tensor==1.14.0) (1.2.2)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->tensor2tensor==1.14.0) (1.3.2)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from flask->tensor2tensor==1.14.0) (1.1.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from flask->tensor2tensor==1.14.0) (7.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from flask->tensor2tensor==1.14.0) (2.10.3)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from flask->tensor2tensor==1.14.0) (0.16.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->tensor2tensor==1.14.0) (0.46)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tensor2tensor==1.14.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tensor2tensor==1.14.0) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tensor2tensor==1.14.0) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tensor2tensor==1.14.0) (3.0.4)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.6/dist-packages (from gunicorn->tensor2tensor==1.14.0) (42.0.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy->tensor2tensor==1.14.0) (1.1.0)
# Requirement already satisfied: greenlet>=0.4.14; platform_python_implementation == "CPython" in /usr/local/lib/python3.6/dist-packages (from gevent->tensor2tensor==1.14.0) (0.4.15)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client->tensor2tensor==1.14.0) (4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client->tensor2tensor==1.14.0) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client->tensor2tensor==1.14.0) (0.2.7)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client->tensor2tensor==1.14.0) (0.11.3)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client->tensor2tensor==1.14.0) (1.4.2)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client->tensor2tensor==1.14.0) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client->tensor2tensor==1.14.0) (3.0.0)
# Requirement already satisfied: googleapis-common-protos in /usr/local/lib/python3.6/dist-packages (from tensorflow-metadata->tensorflow-datasets->tensor2tensor==1.14.0) (1.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->flask->tensor2tensor==1.14.0) (1.1.1)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client->tensor2tensor==1.14.0) (4.0.0)
# Installing collected packages: tensor2tensor
#   Found existing installation: tensor2tensor 1.14.1
#     Uninstalling tensor2tensor-1.14.1:
#       Successfully uninstalled tensor2tensor-1.14.1
# Successfully installed tensor2tensor-1.14.0

# %% [markdown]
# Run the modified download.sh  and the run.sh powershell scripts. They automatically split paragraphs into sentences, translate English sentences to French and then translate them back into English. Finally, they return the paraphrased sentences into paragraphs.
#
# **This may take a while.**

# %%
# !bash download.sh
# !bash run.sh
# Out:
# --2019-12-19 23:39:50--  https://storage.googleapis.com/uda_model/text/back_trans_checkpoints.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.195.128, 2607:f8b0:400e:c08::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4587552274 (4.3G) [application/zip]
# Saving to: ‘back_trans_checkpoints.zip’
#
# back_trans_checkpoi 100%[===================>]   4.27G  85.7MB/s    in 85s
#
# 2019-12-19 23:41:16 (51.2 MB/s) - ‘back_trans_checkpoints.zip’ saved [4587552274/4587552274]
#
# Archive:  back_trans_checkpoints.zip
# replace checkpoints/enfr/model.ckpt-500000.index? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace checkpoints/enfr/model.ckpt-500000.index? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: checkpoints/enfr/model.ckpt-500000.index
#   inflating: checkpoints/enfr/model.ckpt-500000.data-00001-of-00002  y
# y
#
#   inflating: checkpoints/enfr/model.ckpt-500000.meta
#   inflating: checkpoints/enfr/model.ckpt-500000.data-00000-of-00002
#   inflating: checkpoints/vocab.translate_enfr_wmt32k.32768.subwords
#   inflating: checkpoints/fren/model.ckpt-500000.index
#   inflating: checkpoints/fren/model.ckpt-500000.data-00001-of-00002  y
#
#   inflating: checkpoints/fren/model.ckpt-500000.meta
#   inflating: checkpoints/fren/model.ckpt-500000.data-00000-of-00002
# run.sh: line 21: $'\nreplicas: An argument for parallel preprocessing. For example, when replicas=3,\nwe divide the data into three parts, and only process one part\naccording to the worker_id.\n': command not found
# run.sh: line 28: $'\ninput_file: The file to be back translated. We assume that each paragraph is in\na separate line\n': command not found
# run.sh: line 34: $'\nsampling_temp: The sampling temperature for translation. See README.md for more\ndetails.\n': command not found
# *** spliting paragraph ***
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From split_paragraphs.py:91: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1219 23:44:43.404194 140364481165184 deprecation_wrapper.py:119] From split_paragraphs.py:91: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:loading input data
# I1219 23:44:43.404385 140364481165184 split_paragraphs.py:91] loading input data
# WARNING:tensorflow:From split_paragraphs.py:92: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1219 23:44:43.404516 140364481165184 deprecation_wrapper.py:119] From split_paragraphs.py:92: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# INFO:tensorflow:finished loading input data
# I1219 23:44:43.458746 140364481165184 split_paragraphs.py:94] finished loading input data
# INFO:tensorflow:processing data from 0 to 16840
# I1219 23:44:43.458970 140364481165184 split_paragraphs.py:82] processing data from 0 to 16840
# INFO:tensorflow:splitting sentence
# I1219 23:44:43.459213 140364481165184 split_paragraphs.py:103] splitting sentence
# INFO:tensorflow:splitting sentence 0
# I1219 23:44:43.470833 140364481165184 split_paragraphs.py:111] splitting sentence 0
# INFO:tensorflow:splitting sentence 100
# I1219 23:44:43.478306 140364481165184 split_paragraphs.py:111] splitting sentence 100
# INFO:tensorflow:splitting sentence 200
# I1219 23:44:43.484419 140364481165184 split_paragraphs.py:111] splitting sentence 200
# INFO:tensorflow:splitting sentence 300
# I1219 23:44:43.490654 140364481165184 split_paragraphs.py:111] splitting sentence 300
# INFO:tensorflow:splitting sentence 400
# I1219 23:44:43.497399 140364481165184 split_paragraphs.py:111] splitting sentence 400
# INFO:tensorflow:splitting sentence 500
# I1219 23:44:43.503841 140364481165184 split_paragraphs.py:111] splitting sentence 500
# INFO:tensorflow:splitting sentence 600
# I1219 23:44:43.510592 140364481165184 split_paragraphs.py:111] splitting sentence 600
# INFO:tensorflow:splitting sentence 700
# I1219 23:44:43.521389 140364481165184 split_paragraphs.py:111] splitting sentence 700
# INFO:tensorflow:splitting sentence 800
# I1219 23:44:43.532119 140364481165184 split_paragraphs.py:111] splitting sentence 800
# INFO:tensorflow:splitting sentence 900
# I1219 23:44:43.538652 140364481165184 split_paragraphs.py:111] splitting sentence 900
# INFO:tensorflow:splitting sentence 1000
# I1219 23:44:43.544960 140364481165184 split_paragraphs.py:111] splitting sentence 1000
# INFO:tensorflow:splitting sentence 1100
# I1219 23:44:43.551661 140364481165184 split_paragraphs.py:111] splitting sentence 1100
# INFO:tensorflow:splitting sentence 1200
# I1219 23:44:43.558204 140364481165184 split_paragraphs.py:111] splitting sentence 1200
# INFO:tensorflow:splitting sentence 1300
# I1219 23:44:43.565213 140364481165184 split_paragraphs.py:111] splitting sentence 1300
# INFO:tensorflow:splitting sentence 1400
# I1219 23:44:43.571957 140364481165184 split_paragraphs.py:111] splitting sentence 1400
# INFO:tensorflow:splitting sentence 1500
# I1219 23:44:43.578406 140364481165184 split_paragraphs.py:111] splitting sentence 1500
# INFO:tensorflow:splitting sentence 1600
# I1219 23:44:43.584882 140364481165184 split_paragraphs.py:111] splitting sentence 1600
# INFO:tensorflow:splitting sentence 1700
# I1219 23:44:43.590947 140364481165184 split_paragraphs.py:111] splitting sentence 1700
# INFO:tensorflow:splitting sentence 1800
# I1219 23:44:43.597478 140364481165184 split_paragraphs.py:111] splitting sentence 1800
# INFO:tensorflow:splitting sentence 1900
# I1219 23:44:43.601883 140364481165184 split_paragraphs.py:111] splitting sentence 1900
# INFO:tensorflow:splitting sentence 2000
# I1219 23:44:43.606592 140364481165184 split_paragraphs.py:111] splitting sentence 2000
# INFO:tensorflow:splitting sentence 2100
# I1219 23:44:43.611481 140364481165184 split_paragraphs.py:111] splitting sentence 2100
# INFO:tensorflow:splitting sentence 2200
# I1219 23:44:43.615814 140364481165184 split_paragraphs.py:111] splitting sentence 2200
# INFO:tensorflow:splitting sentence 2300
# I1219 23:44:43.620011 140364481165184 split_paragraphs.py:111] splitting sentence 2300
# INFO:tensorflow:splitting sentence 2400
# I1219 23:44:43.624299 140364481165184 split_paragraphs.py:111] splitting sentence 2400
# INFO:tensorflow:splitting sentence 2500
# I1219 23:44:43.628399 140364481165184 split_paragraphs.py:111] splitting sentence 2500
# INFO:tensorflow:splitting sentence 2600
# I1219 23:44:43.632713 140364481165184 split_paragraphs.py:111] splitting sentence 2600
# INFO:tensorflow:splitting sentence 2700
# I1219 23:44:43.639203 140364481165184 split_paragraphs.py:111] splitting sentence 2700
# INFO:tensorflow:splitting sentence 2800
# I1219 23:44:43.644828 140364481165184 split_paragraphs.py:111] splitting sentence 2800
# INFO:tensorflow:splitting sentence 2900
# I1219 23:44:43.652920 140364481165184 split_paragraphs.py:111] splitting sentence 2900
# INFO:tensorflow:splitting sentence 3000
# I1219 23:44:43.657809 140364481165184 split_paragraphs.py:111] splitting sentence 3000
# INFO:tensorflow:splitting sentence 3100
# I1219 23:44:43.662682 140364481165184 split_paragraphs.py:111] splitting sentence 3100
# INFO:tensorflow:splitting sentence 3200
# I1219 23:44:43.666967 140364481165184 split_paragraphs.py:111] splitting sentence 3200
# INFO:tensorflow:splitting sentence 3300
# I1219 23:44:43.671534 140364481165184 split_paragraphs.py:111] splitting sentence 3300
# INFO:tensorflow:splitting sentence 3400
# I1219 23:44:43.676177 140364481165184 split_paragraphs.py:111] splitting sentence 3400
# INFO:tensorflow:splitting sentence 3500
# I1219 23:44:43.680265 140364481165184 split_paragraphs.py:111] splitting sentence 3500
# INFO:tensorflow:splitting sentence 3600
# I1219 23:44:43.685212 140364481165184 split_paragraphs.py:111] splitting sentence 3600
# INFO:tensorflow:splitting sentence 3700
# I1219 23:44:43.690744 140364481165184 split_paragraphs.py:111] splitting sentence 3700
# INFO:tensorflow:splitting sentence 3800
# I1219 23:44:43.696323 140364481165184 split_paragraphs.py:111] splitting sentence 3800
# INFO:tensorflow:splitting sentence 3900
# I1219 23:44:43.702784 140364481165184 split_paragraphs.py:111] splitting sentence 3900
# INFO:tensorflow:splitting sentence 4000
# I1219 23:44:43.708834 140364481165184 split_paragraphs.py:111] splitting sentence 4000
# INFO:tensorflow:splitting sentence 4100
# I1219 23:44:43.714259 140364481165184 split_paragraphs.py:111] splitting sentence 4100
# INFO:tensorflow:splitting sentence 4200
# I1219 23:44:43.720109 140364481165184 split_paragraphs.py:111] splitting sentence 4200
# INFO:tensorflow:splitting sentence 4300
# I1219 23:44:43.729229 140364481165184 split_paragraphs.py:111] splitting sentence 4300
# INFO:tensorflow:splitting sentence 4400
# I1219 23:44:43.735329 140364481165184 split_paragraphs.py:111] splitting sentence 4400
# INFO:tensorflow:splitting sentence 4500
# I1219 23:44:43.741832 140364481165184 split_paragraphs.py:111] splitting sentence 4500
# INFO:tensorflow:splitting sentence 4600
# I1219 23:44:43.748569 140364481165184 split_paragraphs.py:111] splitting sentence 4600
# INFO:tensorflow:splitting sentence 4700
# I1219 23:44:43.755096 140364481165184 split_paragraphs.py:111] splitting sentence 4700
# INFO:tensorflow:splitting sentence 4800
# I1219 23:44:43.761879 140364481165184 split_paragraphs.py:111] splitting sentence 4800
# INFO:tensorflow:splitting sentence 4900
# I1219 23:44:43.768863 140364481165184 split_paragraphs.py:111] splitting sentence 4900
# INFO:tensorflow:splitting sentence 5000
# I1219 23:44:43.775302 140364481165184 split_paragraphs.py:111] splitting sentence 5000
# INFO:tensorflow:splitting sentence 5100
# I1219 23:44:43.781992 140364481165184 split_paragraphs.py:111] splitting sentence 5100
# INFO:tensorflow:splitting sentence 5200
# I1219 23:44:43.788072 140364481165184 split_paragraphs.py:111] splitting sentence 5200
# INFO:tensorflow:splitting sentence 5300
# I1219 23:44:43.794574 140364481165184 split_paragraphs.py:111] splitting sentence 5300
# INFO:tensorflow:splitting sentence 5400
# I1219 23:44:43.800993 140364481165184 split_paragraphs.py:111] splitting sentence 5400
# INFO:tensorflow:splitting sentence 5500
# I1219 23:44:43.807860 140364481165184 split_paragraphs.py:111] splitting sentence 5500
# INFO:tensorflow:splitting sentence 5600
# I1219 23:44:43.815062 140364481165184 split_paragraphs.py:111] splitting sentence 5600
# INFO:tensorflow:splitting sentence 5700
# I1219 23:44:43.822980 140364481165184 split_paragraphs.py:111] splitting sentence 5700
# INFO:tensorflow:splitting sentence 5800
# I1219 23:44:43.829611 140364481165184 split_paragraphs.py:111] splitting sentence 5800
# INFO:tensorflow:splitting sentence 5900
# I1219 23:44:43.835971 140364481165184 split_paragraphs.py:111] splitting sentence 5900
# INFO:tensorflow:splitting sentence 6000
# I1219 23:44:43.842515 140364481165184 split_paragraphs.py:111] splitting sentence 6000
# INFO:tensorflow:splitting sentence 6100
# I1219 23:44:43.847362 140364481165184 split_paragraphs.py:111] splitting sentence 6100
# INFO:tensorflow:splitting sentence 6200
# I1219 23:44:43.852159 140364481165184 split_paragraphs.py:111] splitting sentence 6200
# INFO:tensorflow:splitting sentence 6300
# I1219 23:44:43.857124 140364481165184 split_paragraphs.py:111] splitting sentence 6300
# INFO:tensorflow:splitting sentence 6400
# I1219 23:44:43.861656 140364481165184 split_paragraphs.py:111] splitting sentence 6400
# INFO:tensorflow:splitting sentence 6500
# I1219 23:44:43.865894 140364481165184 split_paragraphs.py:111] splitting sentence 6500
# INFO:tensorflow:splitting sentence 6600
# I1219 23:44:43.869724 140364481165184 split_paragraphs.py:111] splitting sentence 6600
# INFO:tensorflow:splitting sentence 6700
# I1219 23:44:43.873858 140364481165184 split_paragraphs.py:111] splitting sentence 6700
# INFO:tensorflow:splitting sentence 6800
# I1219 23:44:43.877680 140364481165184 split_paragraphs.py:111] splitting sentence 6800
# INFO:tensorflow:splitting sentence 6900
# I1219 23:44:43.881597 140364481165184 split_paragraphs.py:111] splitting sentence 6900
# INFO:tensorflow:splitting sentence 7000
# I1219 23:44:43.887633 140364481165184 split_paragraphs.py:111] splitting sentence 7000
# INFO:tensorflow:splitting sentence 7100
# I1219 23:44:43.893509 140364481165184 split_paragraphs.py:111] splitting sentence 7100
# INFO:tensorflow:splitting sentence 7200
# I1219 23:44:43.898203 140364481165184 split_paragraphs.py:111] splitting sentence 7200
# INFO:tensorflow:splitting sentence 7300
# INFO:tensorflow:splitting sentence 14800
# I1219 23:44:44.357109 140364481165184 split_paragraphs.py:111] splitting sentence 14800
# INFO:tensorflow:splitting sentence 14900
# I1219 23:44:44.361521 140364481165184 split_paragraphs.py:111] splitting sentence 14900
# INFO:tensorflow:splitting sentence 15000
# I1219 23:44:44.365615 140364481165184 split_paragraphs.py:111] splitting sentence 15000
# INFO:tensorflow:splitting sentence 15100
# I1219 23:44:44.369331 140364481165184 split_paragraphs.py:111] splitting sentence 15100
# INFO:tensorflow:splitting sentence 15200
# I1219 23:44:44.373651 140364481165184 split_paragraphs.py:111] splitting sentence 15200
# INFO:tensorflow:splitting sentence 15300
# I1219 23:44:44.377290 140364481165184 split_paragraphs.py:111] splitting sentence 15300
# INFO:tensorflow:splitting sentence 15400
# I1219 23:44:44.382550 140364481165184 split_paragraphs.py:111] splitting sentence 15400
# INFO:tensorflow:splitting sentence 15500
# I1219 23:44:44.388381 140364481165184 split_paragraphs.py:111] splitting sentence 15500
# INFO:tensorflow:splitting sentence 15600
# I1219 23:44:44.393998 140364481165184 split_paragraphs.py:111] splitting sentence 15600
# INFO:tensorflow:splitting sentence 15700
# I1219 23:44:44.399849 140364481165184 split_paragraphs.py:111] splitting sentence 15700
# INFO:tensorflow:splitting sentence 15800
# I1219 23:44:44.405390 140364481165184 split_paragraphs.py:111] splitting sentence 15800
# INFO:tensorflow:splitting sentence 15900
# I1219 23:44:44.410791 140364481165184 split_paragraphs.py:111] splitting sentence 15900
# INFO:tensorflow:splitting sentence 16000
# I1219 23:44:44.416279 140364481165184 split_paragraphs.py:111] splitting sentence 16000
# INFO:tensorflow:splitting sentence 16100
# I1219 23:44:44.420656 140364481165184 split_paragraphs.py:111] splitting sentence 16100
# INFO:tensorflow:splitting sentence 16200
# I1219 23:44:44.425210 140364481165184 split_paragraphs.py:111] splitting sentence 16200
# INFO:tensorflow:splitting sentence 16300
# I1219 23:44:44.431061 140364481165184 split_paragraphs.py:111] splitting sentence 16300
# INFO:tensorflow:splitting sentence 16400
# I1219 23:44:44.437258 140364481165184 split_paragraphs.py:111] splitting sentence 16400
# INFO:tensorflow:splitting sentence 16500
# I1219 23:44:44.447286 140364481165184 split_paragraphs.py:111] splitting sentence 16500
# INFO:tensorflow:splitting sentence 16600
# I1219 23:44:44.453959 140364481165184 split_paragraphs.py:111] splitting sentence 16600
# INFO:tensorflow:splitting sentence 16700
# I1219 23:44:44.459781 140364481165184 split_paragraphs.py:111] splitting sentence 16700
# INFO:tensorflow:splitting sentence 16800
# I1219 23:44:44.466729 140364481165184 split_paragraphs.py:111] splitting sentence 16800
# INFO:tensorflow:finished spliting paragraphs
# I1219 23:44:44.469678 140364481165184 split_paragraphs.py:137] finished spliting paragraphs
# *** forward translation ***
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/adafactor.py:27: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/multistep_optimizer.py:32: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/models/research/glow_init_hook.py:25: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/models/research/neural_stack.py:38: The name tf.nn.rnn_cell.RNNCell is deprecated. Please use tf.compat.v1.nn.rnn_cell.RNNCell instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/rl/gym_utils.py:235: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:111: The name tf.OptimizerOptions is deprecated. Please use tf.compat.v1.OptimizerOptions instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_gan/python/estimator/tpu_gan_estimator.py:42: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.
#
# WARNING:tensorflow:From /usr/local/bin/t2t-decoder:16: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/bin/t2t-decoder:16: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /usr/local/bin/t2t-decoder:17: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:839: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W1219 23:44:53.259263 140719051229056 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:839: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# INFO:tensorflow:Overriding hparams in transformer_big with sampling_method=random,sampling_temp=0.8
# I1219 23:44:53.268409 140719051229056 hparams_lib.py:55] Overriding hparams in transformer_big with sampling_method=random,sampling_temp=0.8
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/data_generators/text_encoder.py:938: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W1219 23:44:53.268830 140719051229056 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/data_generators/text_encoder.py:938: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/data_generators/text_encoder.py:940: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1219 23:44:53.269362 140719051229056 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/data_generators/text_encoder.py:940: The name tf.gfile.Open is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:123: The name tf.GraphOptions is deprecated. Please use tf.compat.v1.GraphOptions instead.
#
# W1219 23:44:53.391505 140719051229056 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:123: The name tf.GraphOptions is deprecated. Please use tf.compat.v1.GraphOptions instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:129: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W1219 23:44:53.391762 140719051229056 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:129: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:242: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# W1219 23:44:53.391932 140719051229056 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:242: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# INFO:tensorflow:Configuring DataParallelism to replicate the model.
# I1219 23:44:53.392108 140719051229056 trainer_lib.py:265] Configuring DataParallelism to replicate the model.
# INFO:tensorflow:schedule=continuous_train_and_eval
# I1219 23:44:53.392180 140719051229056 devices.py:76] schedule=continuous_train_and_eval
# INFO:tensorflow:worker_gpu=1
# I1219 23:44:53.392231 140719051229056 devices.py:77] worker_gpu=1
# INFO:tensorflow:sync=False
# I1219 23:44:53.392277 140719051229056 devices.py:78] sync=False
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/devices.py:139: The name tf.logging.warn is deprecated. Please use tf.compat.v1.logging.warn instead.
#
# W1219 23:44:53.392346 140719051229056 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/devices.py:139: The name tf.logging.warn is deprecated. Please use tf.compat.v1.logging.warn instead.
#
# WARNING:tensorflow:Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# W1219 23:44:53.392406 140719051229056 devices.py:141] Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# INFO:tensorflow:datashard_devices: ['gpu:0']
# I1219 23:44:53.392987 140719051229056 devices.py:170] datashard_devices: ['gpu:0']
# INFO:tensorflow:caching_devices: None
# I1219 23:44:53.393067 140719051229056 devices.py:171] caching_devices: None
# INFO:tensorflow:ps_devices: ['gpu:0']
# I1219 23:44:53.393429 140719051229056 devices.py:172] ps_devices: ['gpu:0']
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ffb410ca320>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_protocol': None, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# isolate_session_state: true
# , '_save_checkpoints_steps': 1000, '_keep_checkpoint_max': 20, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/t2t', 'use_tpu': False, 't2t_device_info': {'num_async_replicas': 1}, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7ffb410ca390>}
# I1219 23:44:53.393940 140719051229056 estimator.py:209] Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ffb410ca320>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_train_distribute': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_device_fn': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_protocol': None, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# isolate_session_state: true
# , '_save_checkpoints_steps': 1000, '_keep_checkpoint_max': 20, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/t2t', 'use_tpu': False, 't2t_device_info': {'num_async_replicas': 1}, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7ffb410ca390>}
# WARNING:tensorflow:Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7ffb41abbf28>) includes params argument, but params are not passed to Estimator.
# W1219 23:44:53.394181 140719051229056 model_fn.py:630] Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7ffb41abbf28>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Performing decoding from file (back_trans_data/forward_src/file_0_of_1.txt).
# I1219 23:44:53.400949 140719051229056 decoding.py:415] Performing decoding from file (back_trans_data/forward_src/file_0_of_1.txt).
# INFO:tensorflow:Getting sorted inputs
# I1219 23:44:53.401025 140719051229056 decoding.py:860] Getting sorted inputs
# INFO:tensorflow: batch 1889
# I1219 23:44:53.482941 140719051229056 decoding.py:673]  batch 1889
# INFO:tensorflow:Decoding batch 0
# I1219 23:44:53.483132 140719051229056 decoding.py:675] Decoding batch 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/decoding.py:617: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W1219 23:44:53.485859 140719051229056 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/decoding.py:617: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/decoding.py:950: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1219 23:44:53.488355 140719051229056 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/decoding.py:950: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:Input graph does not use tf.data.Dataset or contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# W1219 23:44:53.495410 140719051229056 estimator.py:1000] Input graph does not use tf.data.Dataset or contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Calling model_fn.
# I1219 23:44:53.495751 140719051229056 estimator.py:1145] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'infer'
# I1219 23:44:53.496619 140719051229056 t2t_model.py:2248] Setting T2TModel mode to 'infer'
# INFO:tensorflow:Setting hparams.dropout to 0.0
# I1219 23:44:53.497009 140719051229056 t2t_model.py:2248] Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# I1219 23:44:53.497118 140719051229056 t2t_model.py:2248] Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# I1219 23:44:53.497222 140719051229056 t2t_model.py:2248] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# I1219 23:44:53.497302 140719051229056 t2t_model.py:2248] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# I1219 23:44:53.497402 140719051229056 t2t_model.py:2248] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# I1219 23:44:53.497501 140719051229056 t2t_model.py:2248] Setting hparams.relu_dropout to 0.0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/t2t_model.py:244: The name tf.summary.text is deprecated. Please use tf.compat.v1.summary.text instead.
#
# W1219 23:44:53.575043 140719051229056 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/t2t_model.py:244: The name tf.summary.text is deprecated. Please use tf.compat.v1.summary.text instead.
#
# INFO:tensorflow:Greedy Decoding
# I1219 23:44:53.589059 140719051229056 t2t_model.py:2248] Greedy Decoding
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/layers/common_attention.py:857: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1219 23:44:53.754905 140719051229056 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensor2tensor/layers/common_attention.py:857: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W1219 23:44:53.759367 140719051229056 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...
# INFO:tensorflow:Inference results INPUT: "to all those cunts who see my tweets and don’t like or comment can suck my ass exept those couple peeps but bitch you know who you are"
# I1219 23:49:04.301311 140719051229056 decoding.py:152] Inference results INPUT: "to all those cunts who see my tweets and don’t like or comment can suck my ass exept those couple peeps but bitch you know who you are"
# INFO:tensorflow:Inference results OUTPUT: « à toutes les chattes qui voient mes tortues et qui n’aiment pas ou qui ne commentent pas peuvent sucer mon cul exept ces couples admiraient mais mordre toi sais ce que tu tiens ».
# I1219 23:49:04.301489 140719051229056 decoding.py:167] Inference results OUTPUT: « à toutes les chattes qui voient mes tortues et qui n’aiment pas ou qui ne commentent pas peuvent sucer mon cul exept ces couples admiraient mais mordre toi sais ce que tu tiens ».
# INFO:tensorflow:Decoding batch 100
# I1219 23:49:04.302669 140715283236608 decoding.py:675] Decoding batch 100
# INFO:tensorflow:Inference results INPUT: "some cunt at walmart went full psycho on me saying how she had no fucking space to put her shit bitch ur taking up the entire conveyor belt"
# I1219 23:49:06.253719 140719051229056 decoding.py:152] Inference results INPUT: "some cunt at walmart went full psycho on me saying how she had no fucking space to put her shit bitch ur taking up the entire conveyor belt"
# INFO:tensorflow:Inference results OUTPUT: « Certains se sont faits un peu de peine à l’hôpital de Vandershot, me incitant à m’expliquer comment elle n’avait pas d’espace léger pour mettre à profit toute sa petite bite épouvantable qui lui prenait la ceinture des convoyeurs en entier ».
# I1219 23:49:06.254098 140719051229056 decoding.py:167] Inference results OUTPUT: « Certains se sont faits un peu de peine à l’hôpital de Vandershot, me incitant à m’expliquer comment elle n’avait pas d’espace léger pour mettre à profit toute sa petite bite épouvantable qui lui prenait la ceinture des convoyeurs en entier ».
# INFO:tensorflow:Inference results INPUT: "nelly should beware of other woman now trying to accuse him for rape .. ladies after this lady because if one does it others will try it too"
# I1219 23:49:06.254475 140719051229056 decoding.py:152] Inference results INPUT: "nelly should beware of other woman now trying to accuse him for rape .. ladies after this lady because if one does it others will try it too"
# INFO:tensorflow:Inference results OUTPUT: "nelly should beware of other woman now trying to accuse him for rape .. ladies after this lady because if one does it others will try it too" (j'espère que la femme qui est enceinte surveillée qui a une relatifs relation avec les agresseurs) is aware of other woman now trying to accuse him for rape .. ladies after this lady because if one does it others will try it too!).
# I1219 23:49:06.254738 140719051229056 decoding.py:167] Inference results OUTPUT: "nelly should beware of other woman now trying to accuse him for rape .. ladies after this lady because if one does it others will try it too" (j'espère que la femme qui est enceinte surveillée qui a une relatifs relation avec les agresseurs) is aware of other woman now trying to accuse him for rape .. ladies after this lady because if one does it others will try it too!).
# INFO:tensorflow:Inference results INPUT: "there are good men out there women stop accepting ass holes that appear to be right.it is a excuse to turn lesbian cuz of a no good man."
# I1219 23:49:06.255083 140719051229056 decoding.py:152] Inference results INPUT: "there are good men out there women stop accepting ass holes that appear to be right.it is a excuse to turn lesbian cuz of a no good man."
# INFO:tensorflow:Inference results OUTPUT: « Il y a des hommes de bonne qualité là où les femmes arrêtent d’accepter des trous déclenchés par des fesses qui semblent avoir raison.C’est une excuse pour jeter un regard lesbienne sur un homme de bonne qualité.
# I1219 23:49:06.255276 140719051229056 decoding.py:167] Inference results OUTPUT: « Il y a des hommes de bonne qualité là où les femmes arrêtent d’accepter des trous déclenchés par des fesses qui semblent avoir raison.C’est une excuse pour jeter un regard lesbienne sur un homme de bonne qualité.
# INFO:tensorflow:Inference results INPUT: like it legit made her pussy wet to go and talk shit abt me so fuck u ill come beat ur ass thats why u stole a listers"
# I1219 23:49:06.255619 140719051229056 decoding.py:152] Inference results INPUT: like it legit made her pussy wet to go and talk shit abt me so fuck u ill come beat ur ass thats why u stole a listers"
# INFO:tensorflow:Inference results OUTPUT: Le seul secret de la belle baise vient du baiser! Le petit cul ne se fait pas frire et la chatte va en vedette !
# I1219 23:49:06.255771 140719051229056 decoding.py:167] Inference results OUTPUT: Le seul secret de la belle baise vient du baiser! Le petit cul ne se fait pas frire et la chatte va en vedette !
# INFO:tensorflow:Inference results INPUT: "no room for full explanation here but regarding the hysterical women at the kavanaugh hearing, the word hysteria is from a greek word meaning wandering and disconnected uterus.
# I1219 23:49:06.256118 140719051229056 decoding.py:152] Inference results INPUT: "no room for full explanation here but regarding the hysterical women at the kavanaugh hearing, the word hysteria is from a greek word meaning wandering and disconnected uterus.
# INFO:tensorflow:Inference results OUTPUT: « Il n'y a pas lieu ici d'en donner une explication complète, mais à propos des femmes qui sont physiquement physiquement à l'audience de kavanaugh, le mot hystérie vient d'un mot gris signifiant qu'elles errent et qu'elles débranchent l'utérus.
# I1219 23:49:06.256335 140719051229056 decoding.py:167] Inference results OUTPUT: « Il n'y a pas lieu ici d'en donner une explication complète, mais à propos des femmes qui sont physiquement physiquement à l'audience de kavanaugh, le mot hystérie vient d'un mot gris signifiant qu'elles errent et qu'elles débranchent l'utérus.
# INFO:tensorflow:Inference results INPUT: "you are a pussy... stand up or shut up... put youre head above the parapet and make a stance or keep taking the mp wage and stfu x"
# I1219 23:49:06.256668 140719051229056 decoding.py:152] Inference results INPUT: "you are a pussy... stand up or shut up... put youre head above the parapet and make a stance or keep taking the mp wage and stfu x"
ga #kag #potus #trump #news #votered #nodaca #walkaway #americafirst #usa #"
# I1219 23:49:06.259200 140719051229056 decoding.py:152] Inference results INPUT: otoh, #potus #trump is called a racist, bigot, nazi or hitler every day on these fake news shows.#maga #kag #potus #trump #news #votered #nodaca #walkaway #americafirst #usa #"
# INFO:tensorflow:Inference results OUTPUT: os & '!% # %! ! a & & " % ! . . . # # !% !" % & ' & %& '!% !% ) "! " % ( % . C ! "! !" !" " ! % ! " " !
# I1219 23:49:06.259352 140719051229056 decoding.py:167] Inference results OUTPUT: os & '!% # %! ! a & & " % ! . . . # # !% !" % & ' & %& '!% !% ) "! " % ( % . C ! "! !" !" " ! % ! " " !
# INFO:tensorflow:Inference results INPUT: remember to pack a lunch because no one wants to eat lunch with a person whose food will be spit into by the immigrant workers in restaurant kitchens."
# I1219 23:49:06.259747 140719051229056 decoding.py:152] Inference results INPUT: remember to pack a lunch because no one wants to eat lunch with a person whose food will be spit into by the immigrant workers in restaurant kitchens."
# INFO:tensorflow:Inference results OUTPUT: Ne vous souvenez-vous pas d'emballer un repas parce que personne ne désire manger avec une personne dont les aliments seront épissés par les travailleurs immigrants dans les cuisines d'un restaurant.
# I1219 23:49:06.259971 140719051229056 decoding.py:167] Inference results OUTPUT: Ne vous souvenez-vous pas d'emballer un repas parce que personne ne désire manger avec une personne dont les aliments seront épissés par les travailleurs immigrants dans les cuisines d'un restaurant.
# INFO:tensorflow:Inference results INPUT: "whites have to assimilate to non white immigrants in homelands built for us by our ancestors but if they don't assimilate that's perfectly fine.this is an invasion ðÿ˜¡ðÿ˜¡"
# I1219 23:49:06.260425 140719051229056 decoding.py:152] Inference results INPUT: "whites have to assimilate to non white immigrants in homelands built for us by our ancestors but if they don't assimilate that's perfectly fine.this is an invasion ðÿ˜¡ðÿ˜¡"
# INFO:tensorflow:Inference results OUTPUT: « Les Blancs doivent s’assimiler à des non-Blancs dans des terres situées pour nous, bâties pour nos ancêtres, mais s’ils n’assimilent pas, c’est complètement beau. C’est une invasion ðÿ˜¡ðÿ¤ ] »
# I1219 23:49:06.260662 140719051229056 decoding.py:167] Inference results OUTPUT: « Les Blancs doivent s’assimiler à des non-Blancs dans des terres situées pour nous, bâties pour nos ancêtres, mais s’ils n’assimilent pas, c’est complètement beau. C’est une invasion ðÿ˜¡ðÿ¤ ] »
# INFO:tensorflow:Inference results INPUT: now get the word out central americans will not enter the u.s illegally be released to never show up in #immigration court angel families #trump #maga #sendallillegalshome !
# I1219 23:49:06.261019 140719051229056 decoding.py:152] Inference results INPUT: now get the word out central americans will not enter the u.s illegally be released to never show up in #immigration court angel families #trump #maga #sendallillegalshome !
# INFO:tensorflow:Inference results OUTPUT: Maintenant, sortez le mot que les Centroaméricains n'entreront pas illégalement dans les u.s seront libérés pour ne jamais apparaître dans #Immigration Court angel families #trump #maga #sendallillegalshome !
# I1219 23:49:06.261205 140719051229056 decoding.py:167] Inference results OUTPUT: Maintenant, sortez le mot que les Centroaméricains n'entreront pas illégalement dans les u.s seront libérés pour ne jamais apparaître dans #Immigration Court angel families #trump #maga #sendallillegalshome !
# INFO:tensorflow:Inference results INPUT: you have gone too far in chasing mirages, kashmiri women do not sleep around with rss men, you fucking cunt, there is no sanity left in you now.
# I1219 23:49:06.261553 140719051229056 decoding.py:152] Inference results INPUT: you have gone too far in chasing mirages, kashmiri women do not sleep around with rss men, you fucking cunt, there is no sanity left in you now.
# INFO:tensorflow:Inference results OUTPUT: vous avez trop loin en chassant des mirages, les femmes kashmiri ne dorment pas avec les hommes rss, vous la baiser cunte, il ne se reste plus de sanctuarité à vous maintenant.
# I1219 23:49:06.261722 140719051229056 decoding.py:167] Inference results OUTPUT: vous avez trop loin en chassant des mirages, les femmes kashmiri ne dorment pas avec les hommes rss, vous la baiser cunte, il ne se reste plus de sanctuarité à vous maintenant.
# INFO:tensorflow:Inference results INPUT: will do anything to be a member of your guild, you can use her up, she loves to choke on cocks and her pussy stays wet all day!
# I1219 23:49:06.262027 140719051229056 decoding.py:152] Inference results INPUT: will do anything to be a member of your guild, you can use her up, she loves to choke on cocks and her pussy stays wet all day!
# INFO:tensorflow:Inference results OUTPUT: elle fera quoi que ce soit en faire partie, vous pouvez l'utiliser de haut, elle aime se caresser sur des queues et, ce faisant, demeure mouillée toute la journée Australian, et vêtue de ses pipettes en uploads de musique.
# I1219 23:49:06.262216 140719051229056 decoding.py:167] Inference results OUTPUT: elle fera quoi que ce soit en faire partie, vous pouvez l'utiliser de haut, elle aime se caresser sur des queues et, ce faisant, demeure mouillée toute la journée Australian, et vêtue de ses pipettes en uploads de musique.
# INFO:tensorflow:Decoding batch 101
# I1219 23:49:06.262851 140715291629312 decoding.py:675] Decoding batch 101

# %% [markdown]
# For some reason the script does not store the result in a directory. I believe it may be because I did not ensure tensorflow-gpu was installed in the environment, or perhaps my google drive was OOM on this run.
#
# As a workaround I'll copy all of the backtranslated tweets and put them in a text file outside of this code - I'll check if they've been backtranslated by comparing them to the original file - and delete the paraphrase + number indicator at the start of each tweet, so that we get a clean tweet only dataset which we can insert seamlessly into the original tweet file

# %%
# !bash backwardgentopara.bash

# %%
#I've copied the backtranslated file into my google drive, now to preprocess it so it's fit for use


dat = '/content/drive/My Drive/paraphrased1_tweets.txt' 
dat = pd.read_csv(dat, sep = '\t', header = None, names = ['tweet'])
pd.set_option('max_colwidth', 800)
dat.head()

# %% [markdown]
# The tweets above don't seem like proper english - not that the people who most often engage in hate speech are the most educated bunch!
#
# But still the way sentences are communicated seems peculiar - which is exactly what we want! This shows backtranslation has worked and it has doubled the amount of hate speech in our dataset. Upon manual inspection of the tweets this ran true also.
#
# **Now to remove that paraphrase stuff at the start of each tweet**

# %%
def removePara(text_string):  
    
    #We account for whether the number is single, double, triple etc. digit. 
    #Probably could be done a much better way but hey ho
    parsed_text = re.sub(r'(paraphrase )[0-9]:','', text_string) #single digit
    parsed_text = re.sub(r'(paraphrase )[0-9][0-9]:','', parsed_text) #double digit
    parsed_text = re.sub(r'(paraphrase )[0-9][0-9][0-9]:','', parsed_text) #triple digit
    parsed_text = re.sub(r'(paraphrase )[0-9][0-9][0-9][0-9]:','', parsed_text) #quadruple digit
    
    return parsed_text

# %%
dat.tweet = dat.tweet.apply(removePara)
dat.tail()

# %%
dat.to_csv('/content/drive/My Drive/trial/backtranslated_tweets.csv', index = False)
